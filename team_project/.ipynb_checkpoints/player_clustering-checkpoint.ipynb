# %% [markdown]
# # This is a test of clustering players

# %%
from IPython.display import Image
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter("ignore")
# %matplotlib inline

matplotlib.rcParams['figure.figsize'] = [20, 20]
pd.set_option("precision", 5)

# %% [markdown]
# # We load the dataset

# %%
players = pd.read_csv('data/timetomodel.csv')
players.head()
# Out:
#           Player    Pos  Age Team   G    MP   PER  OWS  DWS   WS    ...     \
# 0    Andre Moore  PF-SF   23  TOT  10    50  12.1 -0.1  0.1  0.0    ...
# 1  Armen Gilliam     PF   23  PHO  55  1807  12.9 -0.1  1.4  1.3    ...
# 2    Bart Kofoed     SG   23  UTA  36   225   1.9 -0.4  0.2 -0.1    ...
# 3  Billy Donovan     PG   22  NYK  44   364   8.7 -0.4  0.3 -0.1    ...
# 4    Brad Lohaus     PF   23  BOS  70   718  12.2  0.2  0.8  0.9    ...
#
#    ORB  DRB  TRB  AST  STL  BLK  Year  Allstar  Years_In_NBA        PR
# 0  0.6  0.8  1.4  0.6  0.2  0.1  1988        0             1 -18.54431
# 1  2.4  5.5  7.9  1.3  1.1  0.5  1988        0             1   7.54553
# 2  0.1  0.3  0.4  0.6  0.2  0.0  1988        0             1 -22.17359
# 3  0.1  0.5  0.6  2.0  0.4  0.0  1988        0             1 -18.81340
# 4  0.7  1.3  2.0  0.7  0.3  0.6  1988        0             1 -10.92601
#
# [5 rows x 30 columns]

# %% [markdown]
# We'll drop the seasons of players where it was not yet their 3rd season so those who weren't in the league for long skew the data

# %%
players_atleast_3 = players[players.Years_In_NBA >= 3]
players_atleast_3.head()
# Out:
#             Player Pos  Age Team   G    MP   PER  OWS  DWS   WS    ...     \
# 199  Armen Gilliam  PF   25  TOT  76  2426  16.6  2.3  2.3  4.5    ...
# 204    Brad Lohaus  PF   25  TOT  80  1943  13.6  0.9  2.4  3.3    ...
# 206   Brian Rowsom  PF   24  CHH  44   559  13.6  0.5  0.5  1.0    ...
# 210  Charles Davis  SF   31  CHI  53   429   6.7 -0.5  0.3 -0.2    ...
# 213   Chris Dudley  PF   24  TOT  64  1356   9.5 -1.8  1.9  0.2    ...
#
#      ORB  DRB  TRB  AST  STL  BLK  Year  Allstar  Years_In_NBA        PR
# 199  2.8  5.1  7.9  1.3  0.9  0.7  1990        0             3  16.11847
# 204  1.2  3.8  5.0  2.1  0.7  1.1  1990        0             3   6.76391
# 206  1.0  2.0  3.0  0.5  0.4  0.3  1990        0             3 -10.00229
# 210  0.5  1.1  1.5  0.3  0.2  0.2  1990        0             3 -17.68428
# 213  2.7  3.9  6.6  0.6  0.6  1.1  1990        0             3  -2.73029
#
# [5 rows x 30 columns]

# %%
players.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Team', 'G', 'MP', 'PER', 'OWS', 'DWS', 'WS',
#        'BPM', 'VORP', 'FG', 'FGA', '3P', '3PA', '2P', '2PA', 'FT', 'FTA',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'Year', 'Allstar',
#        'Years_In_NBA', 'PR'],
#       dtype='object')

# %% [markdown]
# We store the numerical columns that we'll use in the model

# %%
value_cols = ['G', 'MP', 'PER', 'OWS', 'DWS', 'WS',
       'BPM', 'VORP', 'FG', 'FGA', '3P', '3PA', '2P', '2PA', 'FT', 'FTA',
       'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK',
       'Years_In_NBA', 'PR']

# %%
players_pivoted = players_atleast_3.pivot_table(index="Player", values=value_cols, columns="Year")

# %%
players_pivoted.reset_index().head()
# Out:
#              Player   2P                                         ...  eFG%  \
# Year                1988 1989 1990 1991 1992 1993 1994 1995 1996 ...  2009
# 0        A.C. Green  3.9  4.8  4.5  3.0  4.5  4.4  5.6  3.3  2.5 ...   NaN
# 1     A.J. Bramlett  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN
# 2      A.J. English  NaN  NaN  NaN  3.5  4.4  NaN  NaN  NaN  NaN ...   NaN
# 3       A.J. Guyton  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN
# 4      A.J. Hammons  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN
#
#
# Year 2010 2011 2012 2013 2014 2015 2016   2017 2018
# 0     NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN  NaN
# 1     NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN  NaN
# 2     NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN  NaN
# 3     NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN  NaN
# 4     NaN  NaN  NaN  NaN  NaN  NaN  NaN  0.464  NaN
#
# [5 rows x 714 columns]

# %%
players_pivoted.shape
# Out:
# (1360, 754)

# %%
player_names = players_pivoted.index
player_names
# Out:
# Index(['A.J. Guyton', 'A.J. Price', 'Aaron Brooks', 'Aaron Gordon',
#        'Aaron Gray', 'Aaron Harrison', 'Aaron McKie', 'Aaron Williams',
#        'Acie Earl', 'Acie Law',
#        ...
#        'Yinka Dare', 'Zach LaVine', 'Zach Randolph', 'Zan Tabak',
#        'Zarko Cabarkapa', 'Zaza Pachulia', 'Zeljko Rebraca', 'Zendon Hamilton',
#        'Zoran Planinic', 'Zydrunas Ilgauskas'],
#       dtype='object', name='Player', length=1360)

# %%
len(player_names)
# Out:
# 1360

# %%
from sklearn.cluster import DBSCAN, KMeans
from sklearn import preprocessing
from sklearn.pipeline import make_pipeline

# %%
imputer = preprocessing.Imputer(strategy="mean")
scaler = preprocessing.StandardScaler()

# %%
processing_pipeline = make_pipeline(
    imputer,
    scaler
)

# %%
players_processed = processing_pipeline.fit_transform(players_pivoted)

# %%
players_processed
# Out:
# array([[ 0.00000000e+00, -1.78775571e-15,  1.41233373e-15, ...,
#          0.00000000e+00,  4.58045066e-16,  4.45332287e-16],
#        [ 0.00000000e+00, -1.78775571e-15,  1.41233373e-15, ...,
#          0.00000000e+00,  4.58045066e-16,  4.45332287e-16],
#        [ 0.00000000e+00, -1.78775571e-15,  1.41233373e-15, ...,
#          1.71114278e-01,  7.00879843e-01,  1.29015097e+00],
#        ...,
#        [ 0.00000000e+00, -1.78775571e-15,  1.41233373e-15, ...,
#          0.00000000e+00,  4.58045066e-16,  4.45332287e-16],
#        [ 0.00000000e+00, -1.78775571e-15,  1.41233373e-15, ...,
#          0.00000000e+00,  4.58045066e-16,  4.45332287e-16],
#        [ 0.00000000e+00, -1.78775571e-15,  1.41233373e-15, ...,
#          0.00000000e+00,  4.58045066e-16,  4.45332287e-16]])

# %%
from scipy.sparse import coo_matrix
players_sparse = coo_matrix(players_processed)

# %%
players_sparse
# Out:
# <1360x754 sparse matrix of type '<class 'numpy.float64'>'
# 	with 699381 stored elements in COOrdinate format>

# %% [markdown]
# SVD manually done; dimensionality not decreased

# %%
from scipy.sparse.linalg import svds

# %%
U,s, V = svds(players_sparse,  k=10)
players_diag_matrix = np.zeros((s.shape[0], s.shape[0]))

for i in range(s.shape[0]):
    players_diag_matrix[i,i] = s[i]

players_full_svd = U @ players_diag_matrix @ V

# %%
players_full_svd.shape
# Out:
# (1360, 754)

# %% [markdown]
# TruncatedSVD used so we can reduce the dimensionality of the data

# %%
from sklearn.decomposition import TruncatedSVD
svd = TruncatedSVD(n_components=3, n_iter=7, random_state=42)

# %%
players_svd = svd.fit_transform(players_sparse)

# %% [markdown]
# DBSCAN used here

# %%
estimator_dbscan = DBSCAN(eps=1, min_samples=150)
dbscan_labels = estimator_dbscan.fit(X=players_svd).labels_

# %%
dbscan_labels
# Out:
# array([-1, -1, -1, ..., -1, -1, -1])

# %%
DBSCAN?

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# %%
GridSearchCV?

# %%
param_space = {
    'eps': np.linspace(0.3, 3, 20),
    'min_samples': range(3, 100)
}

# %%
from sklearn.metrics import silhouette_score

# %% [markdown]
# We had to create our own silhouette scoring function because RandomizedSearchCV assumes true classes are provided, but as DBSCAN/KMeans is unsupervised learning, we provide the labels of the fit as the "true class"

# %%
def silhouette_cv(estimator, X, y=None):
    y_pred = estimator.fit(X).labels_
    print(pd.Series(y_pred).unique())
    print(estimator.get_params())
    return silhouette_score(X, y_pred)

# %%
random = RandomizedSearchCV(estimator=estimator_dbscan,
                           param_distributions=param_space,
                           scoring=silhouette_cv,
)

# %%
random.fit(players_full_svd)
# Out:
# [-1]
# {'algorithm': 'auto', 'eps': 1.1526315789473685, 'leaf_size': 30, 'metric': 'euclidean', 'metric_params': None, 'min_samples': 30, 'n_jobs': 1, 'p': None}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-300-9a7b818740b4> in <module>()
# ----> 1 random.fit(players_full_svd)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     637                                   error_score=self.error_score)
#     638           for parameters, (train, test) in product(candidate_params,
# --> 639                                                    cv.split(X, y, groups)))
#     640
#     641         # if one choose to see train score, "out" will contain train score info
#
# /anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# /anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     623                 return False
#     624             else:
# --> 625                 self._dispatch(tasks)
#     626                 return True
#     627
#
# /anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     586         dispatch_timestamp = time.time()
#     587         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 588         job = self._backend.apply_async(batch, callback=cb)
#     589         self._jobs.append(job)
#     590
#
# /anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     109     def apply_async(self, func, callback=None):
#     110         """Schedule a func to be run"""
# --> 111         result = ImmediateResult(func)
#     112         if callback:
#     113             callback(result)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     330         # Don't delay the application, to avoid keeping the input
#     331         # arguments in memory
# --> 332         self.results = batch()
#     333
#     334     def get(self):
#
# /anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, error_score)
#     486         fit_time = time.time() - start_time
#     487         # _score will return dict if is_multimetric is True
# --> 488         test_scores = _score(estimator, X_test, y_test, scorer, is_multimetric)
#     489         score_time = time.time() - start_time - fit_time
#     490         if return_train_score:
#
# /anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in _score(estimator, X_test, y_test, scorer, is_multimetric)
#     521     """
#     522     if is_multimetric:
# --> 523         return _multimetric_score(estimator, X_test, y_test, scorer)
#     524     else:
#     525         if y_test is None:
#
# /anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in _multimetric_score(estimator, X_test, y_test, scorers)
#     549     for name, scorer in scorers.items():
#     550         if y_test is None:
# --> 551             score = scorer(estimator, X_test)
#     552         else:
#     553             score = scorer(estimator, X_test, y_test)
#
# <ipython-input-263-501a4015bd45> in silhouette_cv(estimator, X, y)
#       3     print(pd.Series(y_pred).unique())
#       4     print(estimator.get_params())
# ----> 5     return silhouette_score(X, y_pred)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/cluster/unsupervised.py in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
#      99         else:
#     100             X, labels = X[indices], labels[indices]
# --> 101     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#     102
#     103
#
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/cluster/unsupervised.py in silhouette_samples(X, labels, metric, **kwds)
#     165     le = LabelEncoder()
#     166     labels = le.fit_transform(labels)
# --> 167     check_number_of_labels(len(le.classes_), X.shape[0])
#     168
#     169     distances = pairwise_distances(X, metric=metric, **kwds)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/cluster/unsupervised.py in check_number_of_labels(n_labels, n_samples)
#      17     if not 1 < n_labels < n_samples:
#      18         raise ValueError("Number of labels is %d. Valid values are 2 "
# ---> 19                          "to n_samples - 1 (inclusive)" % n_labels)
#      20
#      21
#
# ValueError: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)

# %%
clusterer = DBSCAN(algorithm='auto', eps=2.7222222222222223, leaf_size=30,
    metric='euclidean', metric_params=None, min_samples=28, n_jobs=1,
    p=None)

# %%
clusterer.fit(players_svd).labels_
# Out:
# array([ 0,  0,  0, ...,  0,  0, -1])

# %%
silhouette_score(players_svd, clusterer.labels_)
# Out:
# 0.3752284130611319

# %%
print(random.best_estimator_)
# Out:
# DBSCAN(algorithm='auto', eps=2.7222222222222223, leaf_size=30,
#     metric='euclidean', metric_params=None, min_samples=28, n_jobs=1,
#     p=None)

# %%
clusters_dbscan = clusterer.labels_

# %%
pd.DataFrame?

# %%
player_clusters = pd.DataFrame(data=clusters, index=player_names, columns=['cluster'])
player_clusters.cluster.value_counts()
# Out:
# -1    1513
#  0    1004
# Name: cluster, dtype: int64

# %% [markdown]
# Trying KMeans now

# %%
estimator_kmeans = KMeans(random_state=42, n_clusters=5)

estimator_kmeans.fit(players_processed)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=42, tol=0.0001, verbose=0)

# %%
clusters_kmeans = estimator_kmeans.labels_
clusters
# Out:
# array([1, 1, 1, ..., 1, 1, 4], dtype=int32)

# %%
centroids = estimator_kmeans.cluster_centers_
centroids
# Out:
# array([[-9.24446373e-33,  3.59043100e-02,  3.71700893e-02, ...,
#          5.04225635e-02,  1.59661857e-01,  1.77775853e-01],
#        [-5.72877667e-02, -6.46383447e-02, -8.14323909e-02, ...,
#         -9.38223157e-02, -9.91953112e-02, -1.24006512e-01],
#        [-9.24446373e-33, -1.78775571e-15,  1.41233373e-15, ...,
#         -2.13879681e-01,  3.11833271e-01,  8.13854804e-01],
#        [ 2.56693262e+00,  2.82172457e+00,  3.57159810e+00, ...,
#          1.63609266e-01,  1.85637809e-01,  2.03897985e-01],
#        [-7.70371978e-33, -1.78775571e-15,  1.41233373e-15, ...,
#          1.97443932e+00,  1.45413307e+00,  1.43407964e+00]])

# %%
from sklearn.metrics import euclidean_distances

# %%
centroid_distances = euclidean_distances(centroids)
centroid_distances
# Out:
# array([[ 0.        , 27.18082272, 36.97658939, 39.38249389, 38.23717444],
#        [27.18082272,  0.        , 27.57007061, 42.63078437, 35.82766972],
#        [36.97658939, 27.57007061,  0.        , 48.87431355, 37.63082829],
#        [39.38249389, 42.63078437, 48.87431355,  0.        , 53.82597014],
#        [38.23717444, 35.82766972, 37.63082829, 53.82597014,  0.        ]])

# %%
players_pivoted['clusters'] = clusters_kmeans
players_pivoted.head()
# Out:
#                2P                                                ...     \
# Year         1990 1991 1992 1993 1994 1995 1996 1997 1998 1999   ...
# Player                                                           ...
# A.J. Guyton   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   ...
# A.J. Price    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   ...
# Aaron Brooks  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   ...
# Aaron Gordon  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   ...
# Aaron Gray    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   ...
#
#              Years_In_NBA                                          clusters
# Year                 2010 2011 2012 2013 2014 2015 2016 2017  2018
# Player
# A.J. Guyton           NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN        1
# A.J. Price            NaN  NaN  3.0  4.0  5.0  6.0  NaN  NaN   NaN        1
# Aaron Brooks          3.0  4.0  NaN  5.0  6.0  7.0  8.0  9.0  10.0        1
# Aaron Gordon          NaN  NaN  NaN  NaN  NaN  NaN  NaN  3.0   4.0        1
# Aaron Gray            3.0  4.0  5.0  6.0  7.0  NaN  NaN  NaN   NaN        1
#
# [5 rows x 755 columns]

# %% [markdown]
# An important aspect when using K-means is that the distances are related to the variable scales. So we have to normalize the data before using this algorithm for clustering.

# %%
players_atleast_3.drop(columns=['Allstar'], axis=1, inplace=True)
players_atleast_3.head()
# Out:
#             Player Pos  Age Team   G    MP   PER  OWS  DWS   WS    ...     \
# 199  Armen Gilliam  PF   25  TOT  76  2426  16.6  2.3  2.3  4.5    ...
# 204    Brad Lohaus  PF   25  TOT  80  1943  13.6  0.9  2.4  3.3    ...
# 206   Brian Rowsom  PF   24  CHH  44   559  13.6  0.5  0.5  1.0    ...
# 210  Charles Davis  SF   31  CHI  53   429   6.7 -0.5  0.3 -0.2    ...
# 213   Chris Dudley  PF   24  TOT  64  1356   9.5 -1.8  1.9  0.2    ...
#
#      FTA  ORB  DRB  TRB  AST  STL  BLK  Year  Years_In_NBA        PR
# 199  5.5  2.8  5.1  7.9  1.3  0.9  0.7  1990             3  16.11847
# 204  1.3  1.2  3.8  5.0  2.1  0.7  1.1  1990             3   6.76391
# 206  1.9  1.0  2.0  3.0  0.5  0.4  0.3  1990             3 -10.00229
# 210  0.2  0.5  1.1  1.5  0.3  0.2  0.2  1990             3 -17.68428
# 213  2.8  2.7  3.9  6.6  0.6  0.6  1.1  1990             3  -2.73029
#
# [5 rows x 29 columns]

# %%
numerical_data = players_atleast_3[value_cols]
#categorical_data = players_atleast_3[['Allstar']]
numerical_data.head()
# Out:
#       G    MP   PER  OWS  DWS   WS  BPM  VORP   FG   FGA    ...      FT  FTA  \
# 199  76  2426  16.6  2.3  2.3  4.5 -0.3   1.1  6.4  12.4    ...     4.0  5.5
# 204  80  1943  13.6  0.9  2.4  3.3  0.1   1.0  3.8   8.3    ...     0.9  1.3
# 206  44   559  13.6  0.5  0.5  1.0 -3.1  -0.1  1.8   4.1    ...     1.5  1.9
# 210  53   429   6.7 -0.5  0.3 -0.2 -8.1  -0.7  1.1   3.0    ...     0.1  0.2
# 213  64  1356   9.5 -1.8  1.9  0.2 -4.0  -0.7  2.3   5.5    ...     0.9  2.8
#
#      ORB  DRB  TRB  AST  STL  BLK  Years_In_NBA        PR
# 199  2.8  5.1  7.9  1.3  0.9  0.7             3  16.11847
# 204  1.2  3.8  5.0  2.1  0.7  1.1             3   6.76391
# 206  1.0  2.0  3.0  0.5  0.4  0.3             3 -10.00229
# 210  0.5  1.1  1.5  0.3  0.2  0.2             3 -17.68428
# 213  2.7  3.9  6.6  0.6  0.6  1.1             3  -2.73029
#
# [5 rows x 24 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

numerical_data_normalized = MinMaxScaler().fit_transform(numerical_data)
numerical_data_normalized = pd.DataFrame(
                    numerical_data_normalized,
                    columns=numerical_data.columns) 
numerical_data_normalized.head()
# Out:
#          G       MP      PER      OWS      DWS       WS      BPM     VORP  \
# 0  0.89286  0.69613  0.48794  0.28977  0.32673  0.27854  0.77489  0.22069
# 1  0.94048  0.55753  0.47428  0.21023  0.33663  0.22374  0.77848  0.21379
# 2  0.51190  0.16040  0.47428  0.18750  0.14851  0.11872  0.74978  0.13793
# 3  0.61905  0.12310  0.44288  0.13068  0.12871  0.06393  0.70493  0.09655
# 4  0.75000  0.38910  0.45562  0.05682  0.28713  0.08219  0.74170  0.09655
#
#         FG      FGA   ...          FT      FTA      ORB      DRB      TRB  \
# 0  0.52459  0.44604   ...     0.42553  0.41985  0.41176  0.44348  0.48466
# 1  0.31148  0.29856   ...     0.09574  0.09924  0.17647  0.33043  0.30675
# 2  0.14754  0.14748   ...     0.15957  0.14504  0.14706  0.17391  0.18405
# 3  0.09016  0.10791   ...     0.01064  0.01527  0.07353  0.09565  0.09202
# 4  0.18852  0.19784   ...     0.09574  0.21374  0.39706  0.33913  0.40491
#
#        AST      STL      BLK  Years_In_NBA       PR
# 0  0.11111  0.31034  0.15556           0.0  0.52099
# 1  0.17949  0.24138  0.24444           0.0  0.44035
# 2  0.04274  0.13793  0.06667           0.0  0.29581
# 3  0.02564  0.06897  0.04444           0.0  0.22959
# 4  0.05128  0.20690  0.24444           0.0  0.35850
#
# [5 rows x 24 columns]

# %%
players_kmeans_processed_no_allstar = numerical_data_normalized

# %%
players_kmeans_processed = pd.concat([
                            numerical_data_normalized,
                            categorical_data.reset_index(drop=True)
                        ], axis=1
)

# %%
players_kmeans_processed.head()
# Out:
#        Age        G       MP      PER      OWS      DWS       WS      BPM  \
# 0  0.22727  0.89286  0.69613  0.48794  0.28977  0.32673  0.27854  0.77489
# 1  0.22727  0.94048  0.55753  0.47428  0.21023  0.33663  0.22374  0.77848
# 2  0.18182  0.51190  0.16040  0.47428  0.18750  0.14851  0.11872  0.74978
# 3  0.50000  0.61905  0.12310  0.44288  0.13068  0.12871  0.06393  0.70493
# 4  0.18182  0.75000  0.38910  0.45562  0.05682  0.28713  0.08219  0.74170
#
#       VORP       FG   ...         FTA      ORB      DRB      TRB      AST  \
# 0  0.22069  0.52459   ...     0.41985  0.41176  0.44348  0.48466  0.11111
# 1  0.21379  0.31148   ...     0.09924  0.17647  0.33043  0.30675  0.17949
# 2  0.13793  0.14754   ...     0.14504  0.14706  0.17391  0.18405  0.04274
# 3  0.09655  0.09016   ...     0.01527  0.07353  0.09565  0.09202  0.02564
# 4  0.09655  0.18852   ...     0.21374  0.39706  0.33913  0.40491  0.05128
#
#        STL      BLK  Years_In_NBA       PR  Allstar
# 0  0.31034  0.15556           0.0  0.52099        0
# 1  0.24138  0.24444           0.0  0.44035        0
# 2  0.13793  0.06667           0.0  0.29581        0
# 3  0.06897  0.04444           0.0  0.22959        0
# 4  0.20690  0.24444           0.0  0.35850        0
#
# [5 rows x 26 columns]

# %% [markdown]
# We'll change the dtypes to float32 as float64 is too big for some functions

# %%
players_kmeans_processed32 = players_kmeans_processed_no_allstar.astype('float32')
players_kmeans_processed32.dtypes
# Out:
# G               float32
# MP              float32
# PER             float32
# OWS             float32
# DWS             float32
# WS              float32
# BPM             float32
# VORP            float32
# FG              float32
# FGA             float32
# 3P              float32
# 3PA             float32
# 2P              float32
# 2PA             float32
# FT              float32
# FTA             float32
# ORB             float32
# DRB             float32
# TRB             float32
# AST             float32
# STL             float32
# BLK             float32
# Years_In_NBA    float32
# PR              float32
# dtype: object

# %%
players_kmeans_processed32.isnull().values.any()
# Out:
# False

# %%
def cluster_summary(cluster_id):
    cluster = players_pivoted[clusters==cluster_id]
    cluster_summary = cluster.mean().to_dict()
    #cluster[categorical_data.columns].mode().to_dict(orient="records")[0]
    #cluster_summary.update(cluster.mean().to_dict())
    cluster_summary["cluster_id"] = cluster_id
    return cluster_summary

# %%
cluster_summary(1)
# Out:
# {('2P', 1990): 2.430769230769231,
#  ('2P', 1991): 2.817307692307693,
#  ('2P', 1992): 3.0240506329113934,
#  ('2P', 1993): 2.8232142857142852,
#  ('2P', 1994): 2.541984732824429,
#  ('2P', 1995): 2.353896103896105,
#  ('2P', 1996): 2.316959064327485,
#  ('2P', 1997): 2.044086021505375,
#  ('2P', 1998): 1.9954314720812196,
#  ('2P', 1999): 1.8494791666666683,
#  ('2P', 2000): 2.069801980198019,
#  ('2P', 2001): 1.9718309859154932,
#  ('2P', 2002): 2.0838235294117644,
#  ('2P', 2003): 2.0635922330097074,
#  ('2P', 2004): 2.012946428571428,
#  ('2P', 2005): 2.1772532188841205,
#  ('2P', 2006): 2.1424778761061933,
#  ('2P', 2007): 2.2191964285714283,
#  ('2P', 2008): 2.1265306122448986,
#  ('2P', 2009): 2.077142857142856,
#  ('2P', 2010): 2.1253112033195034,
#  ('2P', 2011): 2.1277551020408163,
#  ('2P', 2012): 2.1215447154471536,
#  ('2P', 2013): 2.0741666666666654,
#  ('2P', 2014): 2.079518072289157,
#  ('2P', 2015): 2.0844357976653702,
#  ('2P', 2016): 2.1039999999999996,
#  ('2P', 2017): 2.0937499999999987,
#  ('2P', 2018): 2.23509433962264,
#  ('2PA', 1990): 5.330769230769231,
#  ('2PA', 1991): 5.934615384615385,
#  ('2PA', 1992): 6.243037974683545,
#  ('2PA', 1993): 5.876785714285714,
#  ('2PA', 1994): 5.356488549618322,
#  ('2PA', 1995): 4.875974025974026,
#  ('2PA', 1996): 4.891812865497076,
#  ('2PA', 1997): 4.423118279569893,
#  ('2PA', 1998): 4.393908629441623,
#  ('2PA', 1999): 4.215104166666667,
#  ('2PA', 2000): 4.553960396039604,
#  ('2PA', 2001): 4.423474178403755,
#  ('2PA', 2002): 4.614705882352938,
#  ('2PA', 2003): 4.5917475728155335,
#  ('2PA', 2004): 4.478125000000001,
#  ('2PA', 2005): 4.72703862660944,
#  ('2PA', 2006): 4.600884955752213,
#  ('2PA', 2007): 4.695982142857141,
#  ('2PA', 2008): 4.512653061224492,
#  ('2PA', 2009): 4.37265306122449,
#  ('2PA', 2010): 4.3829875518672194,
#  ('2PA', 2011): 4.468571428571426,
#  ('2PA', 2012): 4.547560975609755,
#  ('2PA', 2013): 4.447499999999995,
#  ('2PA', 2014): 4.3493975903614475,
#  ('2PA', 2015): 4.364591439688713,
#  ('2PA', 2016): 4.3404,
#  ('2PA', 2017): 4.244531250000002,
#  ('2PA', 2018): 4.419622641509433,
#  ('3P', 1990): 0.13461538461538464,
#  ('3P', 1991): 0.19038461538461535,
#  ('3P', 1992): 0.18987341772151892,
#  ('3P', 1993): 0.24107142857142863,
#  ('3P', 1994): 0.21832061068702308,
#  ('3P', 1995): 0.42012987012987035,
#  ('3P', 1996): 0.5122807017543861,
#  ('3P', 1997): 0.4682795698924731,
#  ('3P', 1998): 0.3492385786802032,
#  ('3P', 1999): 0.3307291666666668,
#  ('3P', 2000): 0.35247524752475257,
#  ('3P', 2001): 0.351643192488263,
#  ('3P', 2002): 0.4058823529411763,
#  ('3P', 2003): 0.3601941747572817,
#  ('3P', 2004): 0.3424107142857142,
#  ('3P', 2005): 0.40901287553648064,
#  ('3P', 2006): 0.4371681415929202,
#  ('3P', 2007): 0.5169642857142855,
#  ('3P', 2008): 0.5412244897959181,
#  ('3P', 2009): 0.5624489795918366,
#  ('3P', 2010): 0.521576763485477,
#  ('3P', 2011): 0.5257142857142856,
#  ('3P', 2012): 0.5902439024390238,
#  ('3P', 2013): 0.5929166666666666,
#  ('3P', 2014): 0.6204819277108432,
#  ('3P', 2015): 0.6478599221789888,
#  ('3P', 2016): 0.7004000000000008,
#  ('3P', 2017): 0.7710937500000002,
#  ('3P', 2018): 0.8671698113207549,
#  ('3PA', 1990): 0.42692307692307685,
#  ('3PA', 1991): 0.6326923076923078,
#  ('3PA', 1992): 0.5848101265822786,
#  ('3PA', 1993): 0.7357142857142855,
#  ('3PA', 1994): 0.6809160305343512,
#  ('3PA', 1995): 1.2064935064935067,
#  ('3PA', 1996): 1.4035087719298245,
#  ('3PA', 1997): 1.3440860215053758,
#  ('3PA', 1998): 1.0157360406091362,
#  ('3PA', 1999): 0.9562499999999999,
#  ('3PA', 2000): 1.0118811881188117,
#  ('3PA', 2001): 0.9990610328638501,
#  ('3PA', 2002): 1.170588235294118,
#  ('3PA', 2003): 1.039805825242718,
#  ('3PA', 2004): 0.987053571428571,
#  ('3PA', 2005): 1.1673819742489266,
#  ('3PA', 2006): 1.2269911504424778,
#  ('3PA', 2007): 1.4147321428571435,
#  ('3PA', 2008): 1.5061224489795926,
#  ('3PA', 2009): 1.5351020408163272,
#  ('3PA', 2010): 1.4883817427385901,
#  ('3PA', 2011): 1.4730612244897963,
#  ('3PA', 2012): 1.6955284552845544,
#  ('3PA', 2013): 1.6941666666666675,
#  ('3PA', 2014): 1.7168674698795183,
#  ('3PA', 2015): 1.8587548638132287,
#  ('3PA', 2016): 1.982,
#  ('3PA', 2017): 2.17421875,
#  ('3PA', 2018): 2.4011320754716974,
#  ('AST', 1990): 1.8423076923076924,
#  ('AST', 1991): 2.224999999999999,
#  ('AST', 1992): 2.1518987341772156,
#  ('AST', 1993): 1.9562500000000003,
#  ('AST', 1994): 1.8221374045801528,
#  ('AST', 1995): 1.8077922077922073,
#  ('AST', 1996): 1.7497076023391827,
#  ('AST', 1997): 1.5118279569892485,
#  ('AST', 1998): 1.4984771573604063,
#  ('AST', 1999): 1.3499999999999999,
#  ('AST', 2000): 1.4886138613861384,
#  ('AST', 2001): 1.4915492957746486,
#  ('AST', 2002): 1.5774509803921557,
#  ('AST', 2003): 1.475242718446602,
#  ('AST', 2004): 1.4428571428571437,
#  ('AST', 2005): 1.548068669527897,
#  ('AST', 2006): 1.4814159292035405,
#  ('AST', 2007): 1.6772321428571435,
#  ('AST', 2008): 1.6551020408163253,
#  ('AST', 2009): 1.5040816326530622,
#  ('AST', 2010): 1.4904564315352713,
#  ('AST', 2011): 1.4587755102040814,
#  ('AST', 2012): 1.522357723577236,
#  ('AST', 2013): 1.5979166666666664,
#  ('AST', 2014): 1.5220883534136553,
#  ('AST', 2015): 1.5793774319066154,
#  ('AST', 2016): 1.6348,
#  ('AST', 2017): 1.6265624999999997,
#  ('AST', 2018): 1.74188679245283,
#  ('Age', 1990): 25.615384615384617,
#  ('Age', 1991): 25.423076923076923,
#  ('Age', 1992): 25.873417721518987,
#  ('Age', 1993): 26.044642857142858,
#  ('Age', 1994): 26.47328244274809,
#  ('Age', 1995): 26.993506493506494,
#  ('Age', 1996): 27.415204678362574,
#  ('Age', 1997): 27.768817204301076,
#  ('Age', 1998): 28.14720812182741,
#  ('Age', 1999): 28.4375,
#  ('Age', 2000): 28.39108910891089,
#  ('Age', 2001): 28.624413145539908,
#  ('Age', 2002): 28.416666666666668,
#  ('Age', 2003): 27.95631067961165,
#  ('Age', 2004): 27.857142857142858,
#  ('Age', 2005): 27.811158798283262,
#  ('Age', 2006): 27.72566371681416,
#  ('Age', 2007): 27.607142857142858,
#  ('Age', 2008): 27.738775510204082,
#  ('Age', 2009): 27.538775510204083,
#  ('Age', 2010): 27.651452282157678,
#  ('Age', 2011): 27.526530612244898,
#  ('Age', 2012): 27.80081300813008,
#  ('Age', 2013): 27.7,
#  ('Age', 2014): 27.666666666666668,
#  ('Age', 2015): 27.84046692607004,
#  ('Age', 2016): 27.74,
#  ('Age', 2017): 27.66796875,
#  ('Age', 2018): 27.162264150943397,
#  ('Allstar', 1990): 0.0,
#  ('Allstar', 1991): 0.0,
#  ('Allstar', 1992): 0.0,
#  ('Allstar', 1993): 0.0,
#  ('Allstar', 1994): 0.007633587786259542,
#  ('Allstar', 1995): 0.012987012987012988,
#  ('Allstar', 1996): 0.0,
#  ('Allstar', 1997): 0.005376344086021506,
#  ('Allstar', 1998): 0.005076142131979695,
#  ('Allstar', 1999): 0.0,
#  ('Allstar', 2000): 0.0,
#  ('Allstar', 2001): 0.0,
#  ('Allstar', 2002): 0.00980392156862745,
#  ('Allstar', 2003): 0.0048543689320388345,
#  ('Allstar', 2004): 0.013392857142857142,
#  ('Allstar', 2005): 0.0,
#  ('Allstar', 2006): 0.0,
#  ('Allstar', 2007): 0.008928571428571428,
#  ('Allstar', 2008): 0.0,
#  ('Allstar', 2009): 0.02040816326530612,
#  ('Allstar', 2010): 0.008298755186721992,
#  ('Allstar', 2011): 0.004081632653061225,
#  ('Allstar', 2012): 0.012195121951219513,
#  ('Allstar', 2013): 0.0,
#  ('Allstar', 2014): 0.004016064257028112,
#  ('Allstar', 2015): 0.0038910505836575876,
#  ('Allstar', 2016): 0.0,
#  ('Allstar', 2017): 0.0,
#  ('Allstar', 2018): 0.011320754716981131,
#  ('BLK', 1990): 0.2923076923076922,
#  ('BLK', 1991): 0.41346153846153844,
#  ('BLK', 1992): 0.4101265822784811,
#  ('BLK', 1993): 0.3419642857142861,
#  ('BLK', 1994): 0.34198473282442765,
#  ('BLK', 1995): 0.3324675324675327,
#  ('BLK', 1996): 0.36783625730994185,
#  ('BLK', 1997): 0.3645161290322581,
#  ('BLK', 1998): 0.30507614213198,
#  ('BLK', 1999): 0.2895833333333335,
#  ('BLK', 2000): 0.33415841584158434,
#  ('BLK', 2001): 0.34084507042253526,
#  ('BLK', 2002): 0.34901960784313735,
#  ('BLK', 2003): 0.36650485436893177,
#  ('BLK', 2004): 0.3477678571428574,
#  ('BLK', 2005): 0.3690987124463517,
#  ('BLK', 2006): 0.35707964601769915,
#  ('BLK', 2007): 0.34732142857142817,
#  ('BLK', 2008): 0.36244897959183703,
#  ('BLK', 2009): 0.383265306122449,
#  ('BLK', 2010): 0.39045643153526943,
#  ('BLK', 2011): 0.38816326530612244,
#  ('BLK', 2012): 0.38617886178861793,
#  ('BLK', 2013): 0.38791666666666635,
#  ('BLK', 2014): 0.37510040160642555,
#  ('BLK', 2015): 0.34474708171206225,
#  ('BLK', 2016): 0.3683999999999996,
#  ('BLK', 2017): 0.3464843749999999,
#  ('BLK', 2018): 0.3758490566037732,
#  ('BPM', 1990): -3.3,
#  ('BPM', 1991): -2.4269230769230776,
#  ('BPM', 1992): -2.002531645569621,
#  ('BPM', 1993): -2.1098214285714283,
#  ('BPM', 1994): -2.6824427480916038,
#  ('BPM', 1995): -2.2733766233766235,
#  ('BPM', 1996): -2.323391812865496,
#  ('BPM', 1997): -2.9720430107526865,
#  ('BPM', 1998): -2.9126903553299495,
#  ('BPM', 1999): -3.8354166666666676,
#  ('BPM', 2000): -2.705940594059407,
#  ('BPM', 2001): -2.6178403755868542,
#  ('BPM', 2002): -2.770098039215686,
#  ('BPM', 2003): -2.907766990291262,
#  ('BPM', 2004): -2.816517857142857,
#  ('BPM', 2005): -2.1725321888412026,
#  ('BPM', 2006): -2.6477876106194675,
#  ('BPM', 2007): -2.1616071428571426,
#  ('BPM', 2008): -2.178367346938775,
#  ('BPM', 2009): -2.451020408163266,
#  ('BPM', 2010): -2.302489626556015,
#  ('BPM', 2011): -2.0518367346938766,
#  ('BPM', 2012): -1.854878048780487,
#  ('BPM', 2013): -2.272499999999999,
#  ('BPM', 2014): -2.003212851405622,
#  ('BPM', 2015): -1.6743190661478593,
#  ('BPM', 2016): -1.7619999999999996,
#  ('BPM', 2017): -1.894140625,
#  ('BPM', 2018): -1.6486792452830192,
#  ('DRB', 1990): 1.9423076923076925,
#  ('DRB', 1991): 2.1442307692307696,
#  ('DRB', 1992): 2.248101265822784,
#  ('DRB', 1993): 2.0428571428571427,
#  ('DRB', 1994): 2.020610687022901,
#  ('DRB', 1995): 2.0564935064935077,
#  ('DRB', 1996): 2.228070175438596,
#  ('DRB', 1997): 2.147849462365593,
#  ('DRB', 1998): 1.950253807106599,
#  ('DRB', 1999): 1.991666666666667,
#  ('DRB', 2000): 2.154455445544556,
#  ('DRB', 2001): 2.197183098591548,
#  ('DRB', 2002): 2.2122549019607844,
#  ('DRB', 2003): 2.2121359223300976,
#  ('DRB', 2004): 2.2187500000000013,
#  ('DRB', 2005): 2.3004291845493565,
#  ('DRB', 2006): 2.3323008849557527,
#  ('DRB', 2007): 2.3549107142857157,
#  ('DRB', 2008): 2.41142857142857,
#  ('DRB', 2009): 2.313061224489795,
#  ('DRB', 2010): 2.3473029045643155,
#  ('DRB', 2011): 2.377142857142859,
#  ('DRB', 2012): 2.43739837398374,
#  ('DRB', 2013): 2.379166666666669,
#  ('DRB', 2014): 2.412048192771083,
#  ('DRB', 2015): 2.475875486381323,
#  ('DRB', 2016): 2.5520000000000005,
#  ('DRB', 2017): 2.531640625,
#  ('DRB', 2018): 2.65245283018868,
#  ('DWS', 1990): 1.0461538461538462,
#  ('DWS', 1991): 1.2692307692307692,
#  ('DWS', 1992): 1.2202531645569619,
#  ('DWS', 1993): 1.1348214285714284,
#  ('DWS', 1994): 1.094656488549618,
#  ('DWS', 1995): 1.1181818181818182,
#  ('DWS', 1996): 1.1719298245614032,
#  ('DWS', 1997): 1.0032258064516122,
#  ('DWS', 1998): 0.9751269035532992,
#  ('DWS', 1999): 0.6401041666666665,
#  ('DWS', 2000): 1.0113861386138614,
#  ('DWS', 2001): 0.9906103286384974,
#  ('DWS', 2002): 1.1,
#  ('DWS', 2003): 1.1140776699029125,
#  ('DWS', 2004): 1.155803571428572,
#  ('DWS', 2005): 1.158369098712446,
#  ('DWS', 2006): 1.208407079646018,
#  ('DWS', 2007): 1.2616071428571434,
#  ('DWS', 2008): 1.202857142857143,
#  ('DWS', 2009): 1.1824489795918365,
#  ('DWS', 2010): 1.1244813278008294,
#  ('DWS', 2011): 1.0967346938775502,
#  ('DWS', 2012): 0.8593495934959349,
#  ('DWS', 2013): 1.1129166666666668,
#  ('DWS', 2014): 1.1060240963855417,
#  ('DWS', 2015): 1.1175097276264578,
#  ('DWS', 2016): 1.1639999999999995,
#  ('DWS', 2017): 1.1320312499999998,
#  ('DWS', 2018): 1.1905660377358487,
#  ('FG', 1990): 2.55,
#  ('FG', 1991): 3.01153846153846,
#  ('FG', 1992): 3.2113924050632923,
#  ('FG', 1993): 3.0687500000000005,
#  ('FG', 1994): 2.7641221374045792,
#  ('FG', 1995): 2.781168831168832,
#  ('FG', 1996): 2.828070175438596,
#  ('FG', 1997): 2.512903225806451,
#  ('FG', 1998): 2.3477157360406102,
#  ('FG', 1999): 2.1812500000000017,
#  ('FG', 2000): 2.4207920792079216,
#  ('FG', 2001): 2.323943661971832,
#  ('FG', 2002): 2.4926470588235303,
#  ('FG', 2003): 2.4291262135922316,
#  ('FG', 2004): 2.3544642857142866,
#  ('FG', 2005): 2.58540772532189,
#  ('FG', 2006): 2.579203539823009,
#  ('FG', 2007): 2.7388392857142847,
#  ('FG', 2008): 2.6726530612244885,
#  ('FG', 2009): 2.6432653061224487,
#  ('FG', 2010): 2.6443983402489613,
#  ('FG', 2011): 2.6567346938775516,
#  ('FG', 2012): 2.71178861788618,
#  ('FG', 2013): 2.6620833333333342,
#  ('FG', 2014): 2.7016064257028107,
#  ('FG', 2015): 2.730739299610894,
#  ('FG', 2016): 2.803599999999999,
#  ('FG', 2017): 2.8656249999999996,
#  ('FG', 2018): 3.101132075471698,
#  ('FGA', 1990): 5.765384615384615,
#  ('FGA', 1991): 6.567307692307692,
#  ('FGA', 1992): 6.827848101265821,
#  ('FGA', 1993): 6.616071428571429,
#  ('FGA', 1994): 6.044274809160306,
#  ('FGA', 1995): 6.0857142857142845,
#  ('FGA', 1996): 6.2953216374268965,
#  ('FGA', 1997): 5.762365591397851,
#  ('FGA', 1998): 5.4106598984771574,
#  ('FGA', 1999): 5.176562499999999,
#  ('FGA', 2000): 5.568316831683168,
#  ('FGA', 2001): 5.427699530516429,
#  ('FGA', 2002): 5.785294117647056,
#  ('FGA', 2003): 5.6291262135922295,
#  ('FGA', 2004): 5.458482142857142,
#  ('FGA', 2005): 5.8914163090128735,
#  ('FGA', 2006): 5.830530973451328,
#  ('FGA', 2007): 6.108482142857139,
#  ('FGA', 2008): 6.021632653061225,
#  ('FGA', 2009): 5.908979591836733,
#  ('FGA', 2010): 5.874273858921161,
#  ('FGA', 2011): 5.942040816326531,
#  ('FGA', 2012): 6.241463414634144,
#  ('FGA', 2013): 6.141249999999999,
#  ('FGA', 2014): 6.066666666666668,
#  ('FGA', 2015): 6.220233463035018,
#  ('FGA', 2016): 6.3227999999999955,
#  ('FGA', 2017): 6.422656249999998,
#  ('FGA', 2018): 6.818490566037735,
#  ('FT', 1990): 1.2307692307692308,
#  ('FT', 1991): 1.513461538461538,
#  ('FT', 1992): 1.4291139240506332,
#  ('FT', 1993): 1.5026785714285713,
#  ('FT', 1994): 1.2618320610687026,
#  ('FT', 1995): 1.4389610389610394,
#  ('FT', 1996): 1.3567251461988306,
#  ('FT', 1997): 1.152150537634408,
#  ('FT', 1998): 1.1695431472081217,
#  ('FT', 1999): 1.1203125000000003,
#  ('FT', 2000): 1.1306930693069308,
#  ('FT', 2001): 1.1262910798122066,
#  ('FT', 2002): 1.0892156862745106,
#  ('FT', 2003): 1.142233009708738,
#  ('FT', 2004): 1.1660714285714293,
#  ('FT', 2005): 1.3111587982832613,
#  ('FT', 2006): 1.2783185840707965,
#  ('FT', 2007): 1.3321428571428569,
#  ('FT', 2008): 1.1885714285714293,
#  ('FT', 2009): 1.1983673469387754,
#  ('FT', 2010): 1.1668049792531112,
#  ('FT', 2011): 1.203265306122449,
#  ('FT', 2012): 1.1536585365853658,
#  ('FT', 2013): 1.0920833333333329,
#  ('FT', 2014): 1.1325301204819278,
#  ('FT', 2015): 1.1264591439688711,
#  ('FT', 2016): 1.1724000000000003,
#  ('FT', 2017): 1.165234375,
#  ('FT', 2018): 1.242641509433962,
#  ('FTA', 1990): 1.7307692307692302,
#  ('FTA', 1991): 2.094230769230769,
#  ('FTA', 1992): 1.9493670886075942,
#  ('FTA', 1993): 2.0196428571428564,
#  ('FTA', 1994): 1.747328244274809,
#  ('FTA', 1995): 1.9227272727272724,
#  ('FTA', 1996): 1.8374269005847956,
#  ('FTA', 1997): 1.6037634408602155,
#  ('FTA', 1998): 1.6340101522842647,
#  ('FTA', 1999): 1.5953125000000004,
#  ('FTA', 2000): 1.5410891089108913,
#  ('FTA', 2001): 1.5474178403755858,
#  ('FTA', 2002): 1.4950980392156867,
#  ('FTA', 2003): 1.5470873786407766,
#  ('FTA', 2004): 1.5928571428571439,
#  ('FTA', 2005): 1.797854077253219,
#  ('FTA', 2006): 1.7756637168141596,
#  ('FTA', 2007): 1.8227678571428558,
#  ('FTA', 2008): 1.6191836734693874,
#  ('FTA', 2009): 1.6097959183673467,
#  ('FTA', 2010): 1.596265560165974,
#  ('FTA', 2011): 1.6281632653061224,
#  ('FTA', 2012): 1.5459349593495935,
#  ('FTA', 2013): 1.4770833333333335,
#  ('FTA', 2014): 1.5224899598393575,
#  ('FTA', 2015): 1.5194552529182892,
#  ('FTA', 2016): 1.5640000000000005,
#  ('FTA', 2017): 1.5359374999999995,
#  ('FTA', 2018): 1.6196226415094332,
#  ('G', 1990): 59.11538461538461,
#  ('G', 1991): 61.05769230769231,
#  ('G', 1992): 59.44303797468354,
#  ('G', 1993): 57.267857142857146,
#  ('G', 1994): 53.52671755725191,
#  ('G', 1995): 55.188311688311686,
#  ('G', 1996): 55.55555555555556,
#  ('G', 1997): 52.564516129032256,
#  ('G', 1998): 52.6751269035533,
#  ('G', 1999): 32.807291666666664,
#  ('G', 2000): 54.45544554455446,
#  ('G', 2001): 52.417840375586856,
#  ('G', 2002): 54.1421568627451,
#  ('G', 2003): 55.03398058252427,
#  ('G', 2004): 52.99107142857143,
#  ('G', 2005): 54.97854077253219,
#  ('G', 2006): 55.6858407079646,
#  ('G', 2007): 57.174107142857146,
#  ('G', 2008): 57.077551020408166,
#  ('G', 2009): 54.98367346938775,
#  ('G', 2010): 53.560165975103736,
#  ('G', 2011): 54.57142857142857,
#  ('G', 2012): 43.39430894308943,
#  ('G', 2013): 54.704166666666666,
#  ('G', 2014): 53.100401606425706,
#  ('G', 2015): 55.09338521400778,
#  ('G', 2016): 57.284,
#  ('G', 2017): 55.109375,
#  ('G', 2018): 54.46037735849057,
#  ('MP', 1990): 1206.923076923077,
#  ('MP', 1991): 1306.7307692307693,
#  ('MP', 1992): 1330.3544303797469,
#  ('MP', 1993): 1250.0535714285713,
#  ('MP', 1994): 1162.9618320610687,
#  ('MP', 1995): 1208.2012987012988,
#  ('MP', 1996): 1245.830409356725,
#  ('MP', 1997): 1131.1290322580646,
#  ('MP', 1998): 1087.243654822335,
#  ('MP', 1999): 680.046875,
#  ('MP', 2000): 1105.1881188118812,
#  ('MP', 2001): 1097.3661971830986,
#  ('MP', 2002): 1155.9411764705883,
#  ('MP', 2003): 1191.009708737864,
#  ('MP', 2004): 1126.8973214285713,
#  ('MP', 2005): 1203.1845493562232,
#  ('MP', 2006): 1250.3938053097345,
#  ('MP', 2007): 1316.299107142857,
#  ('MP', 2008): 1275.8081632653061,
#  ('MP', 2009): 1206.7877551020408,
#  ('MP', 2010): 1165.01244813278,
#  ('MP', 2011): 1184.3632653061225,
#  ('MP', 2012): 945.4552845528456,
#  ('MP', 2013): 1180.1666666666667,
#  ('MP', 2014): 1161.2570281124497,
#  ('MP', 2015): 1168.1789883268482,
#  ('MP', 2016): 1222.064,
#  ('MP', 2017): 1219.01171875,
#  ('MP', 2018): 1219.120754716981,
#  ('ORB', 1990): 0.9769230769230772,
#  ('ORB', 1991): 1.1980769230769233,
#  ('ORB', 1992): 1.1227848101265823,
#  ('ORB', 1993): 1.075892857142857,
#  ('ORB', 1994): 0.9954198473282445,
#  ('ORB', 1995): 0.9824675324675325,
#  ('ORB', 1996): 1.008187134502924,
#  ('ORB', 1997): 0.9946236559139788,
#  ('ORB', 1998): 0.9299492385786802,
#  ('ORB', 1999): 0.9411458333333339,
#  ('ORB', 2000): 0.9311881188118811,
#  ('ORB', 2001): 0.9070422535211271,
#  ('ORB', 2002): 0.931372549019608,
#  ('ORB', 2003): 0.9665048543689319,
#  ('ORB', 2004): 0.9495535714285721,
#  ('ORB', 2005): 0.9879828326180263,
#  ('ORB', 2006): 0.9106194690265486,
#  ('ORB', 2007): 0.9098214285714298,
#  ('ORB', 2008): 0.8779591836734693,
#  ('ORB', 2009): 0.8657142857142861,
#  ('ORB', 2010): 0.8634854771784239,
#  ('ORB', 2011): 0.8751020408163261,
#  ('ORB', 2012): 0.9044715447154477,
#  ('ORB', 2013): 0.9029166666666664,
#  ('ORB', 2014): 0.8911646586345381,
#  ('ORB', 2015): 0.853696498054475,
#  ('ORB', 2016): 0.8152,
#  ('ORB', 2017): 0.8226562500000003,
#  ('ORB', 2018): 0.8007547169811328,
#  ('OWS', 1990): 0.35769230769230764,
#  ('OWS', 1991): 1.0788461538461538,
#  ('OWS', 1992): 1.1746835443037973,
#  ('OWS', 1993): 1.2303571428571427,
#  ('OWS', 1994): 1.1145038167938934,
#  ('OWS', 1995): 1.1701298701298697,
#  ('OWS', 1996): 1.1502923976608186,
#  ('OWS', 1997): 0.849462365591398,
#  ('OWS', 1998): 0.9360406091370561,
#  ('OWS', 1999): 0.5265625000000002,
#  ('OWS', 2000): 0.9074257425742575,
#  ('OWS', 2001): 0.8469483568075117,
#  ('OWS', 2002): 1.0142156862745102,
#  ('OWS', 2003): 1.0373786407766985,
#  ('OWS', 2004): 1.044642857142857,
#  ('OWS', 2005): 1.0682403433476397,
#  ('OWS', 2006): 0.9707964601769908,
#  ('OWS', 2007): 1.1241071428571432,
#  ('OWS', 2008): 1.039183673469388,
#  ('OWS', 2009): 1.061224489795918,
#  ('OWS', 2010): 0.9804979253112032,
#  ('OWS', 2011): 1.037142857142858,
#  ('OWS', 2012): 0.8853658536585364,
#  ('OWS', 2013): 1.0608333333333333,
#  ('OWS', 2014): 1.097188755020081,
#  ('OWS', 2015): 1.08715953307393,
#  ('OWS', 2016): 1.1151999999999995,
#  ('OWS', 2017): 1.0652343750000004,
#  ('OWS', 2018): 1.275094339622642,
#  ('PER', 1990): 11.342307692307694,
#  ('PER', 1991): 12.567307692307692,
#  ('PER', 1992): 12.884810126582273,
#  ('PER', 1993): 13.083928571428578,
#  ('PER', 1994): 12.434351145038171,
#  ('PER', 1995): 12.435064935064934,
#  ('PER', 1996): 12.15029239766082,
#  ('PER', 1997): 11.487096774193546,
#  ('PER', 1998): 11.518274111675133,
#  ('PER', 1999): 10.313541666666666,
#  ('PER', 2000): 11.538613861386143,
#  ('PER', 2001): 11.584507042253522,
#  ('PER', 2002): 11.689215686274519,
#  ('PER', 2003): 11.417961165048544,
#  ('PER', 2004): 11.360267857142857,
#  ('PER', 2005): 11.98669527896996,
#  ('PER', 2006): 11.340265486725654,
#  ('PER', 2007): 11.698214285714295,
#  ('PER', 2008): 11.812653061224479,
#  ('PER', 2009): 11.685306122448978,
#  ('PER', 2010): 11.800829875518675,
#  ('PER', 2011): 11.78285714285714,
#  ('PER', 2012): 11.9,
#  ('PER', 2013): 11.765833333333335,
#  ('PER', 2014): 12.539759036144575,
#  ('PER', 2015): 12.473151750972761,
#  ('PER', 2016): 12.5968,
#  ('PER', 2017): 12.382812500000009,
#  ('PER', 2018): 13.05396226415095,
#  ('PR', 1990): -5.9571856776923084,
#  ('PR', 1991): -2.3605821555769237,
#  ('PR', 1992): -2.04505407607595,
#  ('PR', 1993): -3.042883645892856,
#  ('PR', 1994): -3.919251539618319,
#  ('PR', 1995): -2.9901134053896103,
#  ('PR', 1996): -2.618218966198831,
#  ('PR', 1997): -4.050087697473121,
#  ('PR', 1998): -4.981843175888322,
#  ('PR', 1999): -4.458925888697915,
#  ('PR', 2000): -4.726416447871285,
#  ('PR', 2001): -4.618063877558686,
#  ('PR', 2002): -4.10960444637255,
#  ('PR', 2003): -4.008009922961165,
#  ('PR', 2004): -4.023706980044642,
#  ('PR', 2005): -2.8577824424034297,
#  ('PR', 2006): -2.698104473761061,
#  ('PR', 2007): -1.8698783703571444,
#  ('PR', 2008): -2.892138559918367,
#  ('PR', 2009): -3.7003096803673503,
#  ('PR', 2010): -4.37448168298755,
#  ('PR', 2011): -3.3493219900000017,
#  ('PR', 2012): -2.369869039715446,
#  ('PR', 2013): -2.7207231827083325,
#  ('PR', 2014): -2.358035161004018,
#  ('PR', 2015): -2.34559190151751,
#  ('PR', 2016): -2.34759697668,
#  ('PR', 2017): -2.0414271842968748,
#  ('PR', 2018): 0.810835191698113,
#  ('STL', 1990): 0.6730769230769231,
#  ('STL', 1991): 0.7538461538461537,
#  ('STL', 1992): 0.7354430379746836,
#  ('STL', 1993): 0.6803571428571429,
#  ('STL', 1994): 0.6603053435114505,
#  ('STL', 1995): 0.6545454545454545,
#  ('STL', 1996): 0.6508771929824559,
#  ('STL', 1997): 0.636021505376344,
#  ('STL', 1998): 0.6116751269035534,
#  ('STL', 1999): 0.6109375000000001,
#  ('STL', 2000): 0.585148514851485,
#  ('STL', 2001): 0.5882629107981224,
#  ('STL', 2002): 0.602450980392157,
#  ('STL', 2003): 0.5888349514563107,
#  ('STL', 2004): 0.5950892857142857,
#  ('STL', 2005): 0.58755364806867,
#  ('STL', 2006): 0.5579646017699111,
#  ('STL', 2007): 0.5946428571428571,
#  ('STL', 2008): 0.5644897959183669,
#  ('STL', 2009): 0.5636734693877549,
#  ('STL', 2010): 0.5481327800829875,
#  ('STL', 2011): 0.5424489795918369,
#  ('STL', 2012): 0.60609756097561,
#  ('STL', 2013): 0.5808333333333331,
#  ('STL', 2014): 0.5678714859437751,
#  ('STL', 2015): 0.575875486381323,
#  ('STL', 2016): 0.6048,
#  ('STL', 2017): 0.6058593749999996,
#  ('STL', 2018): 0.6384905660377355,
#  ('TRB', 1990): 2.911538461538462,
#  ('TRB', 1991): 3.3403846153846146,
#  ('TRB', 1992): 3.370886075949366,
#  ('TRB', 1993): 3.1196428571428574,
#  ('TRB', 1994): 3.014503816793894,
#  ('TRB', 1995): 3.038961038961039,
#  ('TRB', 1996): 3.2280701754385963,
#  ('TRB', 1997): 3.1419354838709688,
#  ('TRB', 1998): 2.8817258883248726,
#  ('TRB', 1999): 2.9255208333333322,
#  ('TRB', 2000): 3.086633663366338,
#  ('TRB', 2001): 3.1028169014084486,
#  ('TRB', 2002): 3.14362745098039,
#  ('TRB', 2003): 3.1771844660194173,
#  ('TRB', 2004): 3.165178571428572,
#  ('TRB', 2005): 3.291845493562231,
#  ('TRB', 2006): 3.2424778761061943,
#  ('TRB', 2007): 3.259375000000002,
#  ('TRB', 2008): 3.287346938775509,
#  ('TRB', 2009): 3.1759183673469367,
#  ('TRB', 2010): 3.2082987551867235,
#  ('TRB', 2011): 3.2469387755102064,
#  ('TRB', 2012): 3.3390243902439023,
#  ('TRB', 2013): 3.2858333333333314,
#  ('TRB', 2014): 3.3012048192771064,
#  ('TRB', 2015): 3.3217898832684822,
#  ('TRB', 2016): 3.3627999999999987,
#  ('TRB', 2017): 3.35390625,
#  ('TRB', 2018): 3.451320754716983,
#  ('VORP', 1990): -0.12692307692307692,
#  ('VORP', 1991): 0.33461538461538465,
#  ('VORP', 1992): 0.3518987341772153,
#  ('VORP', 1993): 0.3178571428571427,
#  ('VORP', 1994): 0.30992366412213734,
#  ('VORP', 1995): 0.3266233766233766,
#  ('VORP', 1996): 0.3485380116959063,
#  ('VORP', 1997): 0.16505376344086026,
#  ('VORP', 1998): 0.21827411167512686,
#  ('VORP', 1999): 0.11927083333333323,
#  ('VORP', 2000): 0.20346534653465342,
#  ('VORP', 2001): 0.18497652582159613,
#  ('VORP', 2002): 0.29558823529411754,
#  ('VORP', 2003): 0.28252427184466006,
#  ('VORP', 2004): 0.3035714285714287,
#  ('VORP', 2005): 0.3223175965665234,
#  ('VORP', 2006): 0.29955752212389375,
#  ('VORP', 2007): 0.40446428571428555,
#  ('VORP', 2008): 0.33387755102040817,
#  ('VORP', 2009): 0.3853061224489799,
#  ('VORP', 2010): 0.33402489626556015,
#  ('VORP', 2011): 0.3391836734693876,
#  ('VORP', 2012): 0.30406504065040657,
#  ('VORP', 2013): 0.35041666666666643,
#  ('VORP', 2014): 0.4044176706827311,
#  ('VORP', 2015): 0.3642023346303502,
#  ('VORP', 2016): 0.3907999999999998,
#  ('VORP', 2017): 0.345703125,
#  ('VORP', 2018): 0.49924528301886806,
#  ('WS', 1990): 1.3884615384615384,
#  ('WS', 1991): 2.346153846153846,
#  ('WS', 1992): 2.39746835443038,
#  ('WS', 1993): 2.370535714285715,
#  ('WS', 1994): 2.212213740458016,
#  ('WS', 1995): 2.2824675324675323,
#  ('WS', 1996): 2.3216374269005864,
#  ('WS', 1997): 1.8559139784946237,
#  ('WS', 1998): 1.914213197969544,
#  ('WS', 1999): 1.1692708333333337,
#  ('WS', 2000): 1.91980198019802,
#  ('WS', 2001): 1.8403755868544607,
#  ('WS', 2002): 2.1117647058823534,
#  ('WS', 2003): 2.1470873786407774,
#  ('WS', 2004): 2.2058035714285715,
#  ('WS', 2005): 2.22961373390558,
#  ('WS', 2006): 2.1858407079646027,
#  ('WS', 2007): 2.3888392857142855,
#  ('WS', 2008): 2.2481632653061228,
#  ('WS', 2009): 2.241224489795919,
#  ('WS', 2010): 2.103319502074689,
#  ('WS', 2011): 2.1379591836734693,
#  ('WS', 2012): 1.7504065040650398,
#  ('WS', 2013): 2.1766666666666667,
#  ('WS', 2014): 2.204417670682731,
#  ('WS', 2015): 2.2054474708171212,
#  ('WS', 2016): 2.274400000000001,
#  ('WS', 2017): 2.1949218750000004,
#  ('WS', 2018): 2.4630188679245273,
#  ('Years_In_NBA', 1990): 3.0,
#  ('Years_In_NBA', 1991): 3.326923076923077,
#  ('Years_In_NBA', 1992): 3.7468354430379747,
#  ('Years_In_NBA', 1993): 4.0,
#  ('Years_In_NBA', 1994): 4.435114503816794,
#  ('Years_In_NBA', 1995): 4.909090909090909,
#  ('Years_In_NBA', 1996): 5.292397660818714,
#  ('Years_In_NBA', 1997): 5.623655913978495,
#  ('Years_In_NBA', 1998): 6.050761421319797,
#  ('Years_In_NBA', 1999): 6.458333333333333,
#  ('Years_In_NBA', 2000): 6.46039603960396,
#  ('Years_In_NBA', 2001): 6.690140845070423,
#  ('Years_In_NBA', 2002): 6.549019607843137,
#  ('Years_In_NBA', 2003): 6.305825242718447,
#  ('Years_In_NBA', 2004): 6.272321428571429,
#  ('Years_In_NBA', 2005): 6.257510729613734,
#  ('Years_In_NBA', 2006): 6.34070796460177,
#  ('Years_In_NBA', 2007): 6.34375,
#  ('Years_In_NBA', 2008): 6.3795918367346935,
#  ('Years_In_NBA', 2009): 6.420408163265306,
#  ('Years_In_NBA', 2010): 6.551867219917012,
#  ('Years_In_NBA', 2011): 6.530612244897959,
#  ('Years_In_NBA', 2012): 6.890243902439025,
#  ('Years_In_NBA', 2013): 6.808333333333334,
#  ('Years_In_NBA', 2014): 6.7028112449799195,
#  ('Years_In_NBA', 2015): 6.809338521400778,
#  ('Years_In_NBA', 2016): 6.808,
#  ('Years_In_NBA', 2017): 6.765625,
#  ('Years_In_NBA', 2018): 6.339622641509434,
#  ('clusters', ''): 1.0,
#  'cluster_id': 1}

# %% [markdown]
# Plotting the DBSCAN clusters; as you can see, we have too many outliers

# %%
import matplotlib.pyplot as plt

# %%
core_samples_mask = np.zeros_like(clusterer.labels_, dtype=bool)
core_samples_mask[clusterer.core_sample_indices_] = True

# %%
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)

# %%
unique_labels = set(labels)
colors = [plt.cm.Spectral(each)
          for each in np.linspace(0, 1, len(unique_labels))]
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    class_member_mask = (labels == k)

    xy = players_svd[class_member_mask & core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=14)

    xy = players_svd[class_member_mask & ~core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=6)

plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()

# %% [markdown]
# Using KMeans and plotting the heatmap to see characteristics of clusters

# %%
def kmeans_cluster(df, n_clusters=2, test=None):
    model = KMeans(n_clusters=n_clusters, random_state=42)
    clusters = model.fit_predict(df)
    if test is not None:
        test_clusters = model.fit_predict(test)
        print(test_clusters)
    cluster_results = df.copy()
    cluster_results['Cluster'] = clusters
    return cluster_results

def graph_summary_clustering(results):
    cluster_size = results.groupby(['Cluster']).size().reset_index()
    cluster_size.columns = ['Cluster', 'Count']
    cluster_means = results.groupby(['Cluster'], as_index=False).mean()
    cluster_summary = pd.merge(cluster_size, cluster_means, on='Cluster')
    cluster_summary = cluster_summary.drop(["Count"], axis=1).set_index("Cluster")
    return cluster_summary[sorted(cluster_summary.columns)]

# %%
cluster_results = kmeans_cluster(players_kmeans_processed32, 6)
cluster_summary = graph_summary_clustering(cluster_results);

# %%
import seaborn as sns
sns.set_style('dark')
sns.heatmap(cluster_summary.transpose(), annot=True);

# %%
cluster_results['Cluster Name'] = ''
cluster_results['Cluster Name'][cluster_results['Cluster']==0] = 'Bigmen allstar+'
cluster_results['Cluster Name'][cluster_results['Cluster']==1] = 'Bench'
cluster_results['Cluster Name'][cluster_results['Cluster']==2] = 'Bigmen starter'
cluster_results['Cluster Name'][cluster_results['Cluster']==3] = 'Scrubs/Injury shortened'
cluster_results['Cluster Name'][cluster_results['Cluster']==4] = 'Nonbig starter'
cluster_results['Cluster Name'][cluster_results['Cluster']==5] = 'Nonbig allstar+'

players_atleast_3 = players_atleast_3.reset_index().drop('index', axis=1)
players_atleast_3['Cluster Name'] = cluster_results['Cluster Name']

# %%
cluster_results.Cluster
# Out:
# 0       0
# 1       2
# 2       1
# 3       1
# 4       2
# 5       3
# 6       3
# 7       4
# 8       0
# 9       1
# 10      2
# 11      0
# 12      3
# 13      1
# 14      0
# 15      4
# 16      1
# 17      5
# 18      4
# 19      1
# 20      4
# 21      3
# 22      4
# 23      1
# 24      3
# 25      0
# 26      5
# 27      1
# 28      1
# 29      5
#        ..
# 7914    5
# 7915    3
# 7916    1
# 7917    1
# 7918    4
# 7919    1
# 7920    4
# 7921    4
# 7922    2
# 7923    4
# 7924    1
# 7925    4
# 7926    1
# 7927    5
# 7928    2
# 7929    1
# 7930    3
# 7931    3
# 7932    5
# 7933    1
# 7934    4
# 7935    1
# 7936    4
# 7937    4
# 7938    2
# 7939    3
# 7940    4
# 7941    4
# 7942    4
# 7943    1
# Name: Cluster, Length: 7944, dtype: int32

# %%
players_atleast_3.head(20)
# Out:
#            Player Pos  Age Team   G    MP   PER  OWS  DWS    WS  \
# 0   Armen Gilliam  PF   25  TOT  76  2426  16.6  2.3  2.3   4.5
# 1     Brad Lohaus  PF   25  TOT  80  1943  13.6  0.9  2.4   3.3
# 2    Brian Rowsom  PF   24  CHH  44   559  13.6  0.5  0.5   1.0
# 3   Charles Davis  SF   31  CHI  53   429   6.7 -0.5  0.3  -0.2
# 4    Chris Dudley  PF   24  TOT  64  1356   9.5 -1.8  1.9   0.2
# 5      Chris Welp   C   26  TOT  27   198   6.3 -0.2  0.2   0.0
# 6     Dave Hoppen   C   25  CHH  10   135   7.7 -0.1  0.1   0.0
# 7   Dennis Hopson  SG   24  NJN  79  2551  13.6  1.3  1.9   3.1
# 8   Derrick McKey  SF   23  SEA  80  2748  15.6  4.0  2.3   6.3
# 9    Eddie Hughes  PG   29  DEN  60   892   8.3  0.1  0.9   1.0
# 10  Greg Anderson  PF   25  MIL  60  1291  13.0  0.2  1.7   2.0
# 11   Horace Grant  PF   24  CHI  80  2753  16.6  5.3  2.8   8.0
# 12     Jim Farmer  SG   25  SEA  38   400  15.5  0.5  0.3   0.7
# 13       Joe Wolf   C   25  LAC  77  1325   6.8 -1.4  1.2  -0.2
# 14     Ken Norman  SF   25  LAC  70  2334  14.6  0.4  2.6   2.9
# 15    Kenny Smith  PG   24  TOT  79  2421  13.3  1.7  1.0   2.6
# 16   Kevin Gamble  SF   24  BOS  71   990  12.3  1.2  0.7   1.9
# 17  Kevin Johnson  PG   23  PHO  74  2782  22.8  9.0  2.6  11.6
# 18  Lester Conner  PG   30  NJN  82  2355  12.8  1.1  2.6   3.7
# 19     Mark Acres   C   27  ORL  80  1691   8.3  1.1  0.6   1.6
#
#              ...             ORB  DRB  TRB   AST  STL  BLK  Year  \
# 0            ...             2.8  5.1  7.9   1.3  0.9  0.7  1990
# 1            ...             1.2  3.8  5.0   2.1  0.7  1.1  1990
# 2            ...             1.0  2.0  3.0   0.5  0.4  0.3  1990
# 3            ...             0.5  1.1  1.5   0.3  0.2  0.2  1990
# 4            ...             2.7  3.9  6.6   0.6  0.6  1.1  1990
# 5            ...             0.7  1.1  1.8   0.3  0.2  0.3  1990
# 6            ...             1.9  1.7  3.6   0.6  0.2  0.1  1990
# 7            ...             1.4  2.1  3.5   1.9  1.3  0.6  1990
# 8            ...             2.1  4.0  6.1   2.3  1.1  1.0  1990
# 9            ...             0.3  0.9  1.2   1.9  0.8  0.0  1990
# 10           ...             1.9  4.4  6.2   0.4  0.5  0.9  1990
# 11           ...             3.0  4.9  7.9   2.8  1.2  1.1  1990
# 12           ...             0.4  0.7  1.1   0.7  0.4  0.0  1990
# 13           ...             0.8  2.2  3.0   0.8  0.4  0.3  1990
# 14           ...             2.0  4.7  6.7   2.3  1.1  0.8  1990
# 15           ...             0.2  1.8  2.0   5.6  1.0  0.1  1990
# 16           ...             0.6  1.0  1.6   1.7  0.4  0.1  1990
# 17           ...             0.6  3.1  3.6  11.4  1.3  0.2  1990
# 18           ...             1.1  2.1  3.2   4.7  2.1  0.1  1990
# 19           ...             1.9  3.5  5.4   0.8  0.5  0.3  1990
#
#     Years_In_NBA        PR             Cluster Name
# 0              3  16.11847          Bigmen allstar+
# 1              3   6.76391           Bigmen starter
# 2              3 -10.00229                    Bench
# 3              3 -17.68428                    Bench
# 4              3  -2.73029           Bigmen starter
# 5              3 -18.02960  Scrubs/Injury shortened
# 6              3 -14.76186  Scrubs/Injury shortened
# 7              3  11.69767           Nonbig starter
# 8              3  17.79616          Bigmen allstar+
# 9              3 -11.37089                    Bench
# 10             3  -0.61311           Bigmen starter
# 11             3  19.21672          Bigmen allstar+
# 12             3 -10.64881  Scrubs/Injury shortened
# 13             3 -10.83577                    Bench
# 14             3  12.88664          Bigmen allstar+
# 15             3   3.45032           Nonbig starter
# 16             3  -8.85924                    Bench
# 17             3  31.01154          Nonbig allstar+
# 18             3   5.41508           Nonbig starter
# 19             3  -5.31394                    Bench
#
# [20 rows x 30 columns]

# %%
players_atleast_3[players_atleast_3.Player == 'LeBron James']
# Out:
#             Player Pos  Age Team   G    MP   PER   OWS  DWS    WS  \
# 3787  LeBron James  SF   21  CLE  79  3361  28.1  12.0  4.3  16.3
# 4110  LeBron James  SF   22  CLE  78  3190  24.5   8.0  5.7  13.7
# 4436  LeBron James  SF   23  CLE  75  3027  29.1  10.7  4.6  15.2
# 4754  LeBron James  SF   24  CLE  81  3054  31.7  13.7  6.5  20.3
# 5085  LeBron James  SF   25  CLE  76  2966  31.1  13.3  5.2  18.5
# 5428  LeBron James  SF   26  MIA  79  3063  27.3  10.3  5.3  15.6
# 5767  LeBron James  SF   27  MIA  62  2326  30.7  10.0  4.5  14.5
# 6107  LeBron James  PF   28  MIA  76  2877  31.6  14.6  4.7  19.3
# 6447  LeBron James  PF   29  MIA  77  2902  29.3  12.3  3.7  15.9
# 6793  LeBron James  SF   30  CLE  69  2493  25.9   7.4  2.9  10.4
# 7130  LeBron James  SF   31  CLE  76  2709  27.5   9.6  4.0  13.6
# 7471  LeBron James  SF   32  CLE  74  2794  27.0   9.8  3.0  12.9
# 7808  LeBron James  PF   33  CLE  82  3026  28.6  11.0  3.0  14.0
#
#            ...         ORB  DRB  TRB  AST  STL  BLK  Year  Years_In_NBA  \
# 3787       ...         0.9  6.1  7.0  6.6  1.6  0.8  2006             3
# 4110       ...         1.1  5.7  6.7  6.0  1.6  0.7  2007             4
# 4436       ...         1.8  6.1  7.9  7.2  1.8  1.1  2008             5
# 4754       ...         1.3  6.3  7.6  7.2  1.7  1.1  2009             6
# 5085       ...         0.9  6.4  7.3  8.6  1.6  1.0  2010             7
# 5428       ...         1.0  6.5  7.5  7.0  1.6  0.6  2011             8
# 5767       ...         1.5  6.4  7.9  6.2  1.9  0.8  2012             9
# 6107       ...         1.3  6.8  8.0  7.3  1.7  0.9  2013            10
# 6447       ...         1.1  5.9  6.9  6.3  1.6  0.3  2014            11
# 6793       ...         0.7  5.3  6.0  7.4  1.6  0.7  2015            12
# 7130       ...         1.5  6.0  7.4  6.8  1.4  0.6  2016            13
# 7471       ...         1.3  7.3  8.6  8.7  1.2  0.6  2017            14
# 7808       ...         1.2  7.5  8.6  9.1  1.4  0.9  2018            15
#
#             PR     Cluster Name
# 3787  59.55887  Nonbig allstar+
# 4110  51.47710  Nonbig allstar+
# 4436  61.91221  Nonbig allstar+
# 4754  64.93725  Nonbig allstar+
# 5085  66.26000  Nonbig allstar+
# 5428  56.03244  Nonbig allstar+
# 5767  62.94268  Nonbig allstar+
# 6107  62.05442  Nonbig allstar+
# 6447  52.74396  Nonbig allstar+
# 6793  47.33099  Nonbig allstar+
# 7130  51.88188  Nonbig allstar+
# 7471  51.75066  Nonbig allstar+
# 7808  59.17085  Nonbig allstar+
#
# [13 rows x 30 columns]

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2).fit(numerical_data_normalized)
pca_2d = pca.transform(numerical_data_normalized)

# %%
import matplotlib.pyplot as plt

# %%
colors = ['b', 'c', 'y', 'm', 'r', 'k']

bigstar = plt.scatter(cluster_results[cluster_results.Cluster == 0].WS, 
            cluster_results[cluster_results.Cluster == 0].DRB, 
            c=colors[0], alpha=0.7)
bench = plt.scatter(cluster_results[cluster_results.Cluster == 1].WS, 
            cluster_results[cluster_results.Cluster == 1].DRB, 
            c=colors[1], alpha=0.7)
bigstarter = plt.scatter(cluster_results[cluster_results.Cluster == 2].WS, 
            cluster_results[cluster_results.Cluster == 2].DRB, 
            c=colors[2], alpha=0.7)
scrubs = plt.scatter(cluster_results[cluster_results.Cluster == 3].WS, 
            cluster_results[cluster_results.Cluster == 3].DRB, 
            c=colors[3], alpha=0.7)
smallstarter = plt.scatter(cluster_results[cluster_results.Cluster == 4].WS, 
            cluster_results[cluster_results.Cluster == 4].DRB, 
            c=colors[4], alpha=0.7)
smallstar = plt.scatter(cluster_results[cluster_results.Cluster == 5].WS, 
            cluster_results[cluster_results.Cluster == 5].DRB, 
            c=colors[5], alpha=0.7)

#x = plt.set_xlabel('Win Share per Season')
#y = plt.set_ylabel('Defensive Rebounds per Season')

plt.legend((bigstar, bench, bigstarter, scrubs, smallstarter, smallstar),
           ('Bigmen Allstar+', 'Bench', 'Bigmen Starter', 'Scrubs/Injury Shortened', 'Non-big Starter', 'Non-big Allstar+'),
           scatterpoints=1,
           loc='lower left',
           fontsize=8)

plt.show();

# %%
plt?

# %%
cluster_results.Cluster.unique()
# Out:
# array([0, 2, 1, 3, 4, 5])

# %%
from matplotlib.axes import Axes

# %%
plt.style.use('fivethirtyeight')
plt.axes(xlim=(0,1), ylim=(0,1))

plt.scatter(cluster_results[cluster_results.Cluster == 0].WS, 
            cluster_results[cluster_results.Cluster == 0].TRB)
plt.title('Win Share vs DRB for Bigmen Allstar+')
plt.xlabel('Win Share per Season')
plt.ylabel('Rebounds per Season')
# Out:
# Text(0,0.5,'Rebounds per Season')

# %%
plt.style.use('fivethirtyeight')
plt.axes(xlim=(0,1), ylim=(0,1))

plt.scatter(cluster_results[cluster_results.Cluster == 1].WS, 
            cluster_results[cluster_results.Cluster == 1].TRB)
plt.title('Win Share vs DRB for Bench/Kwame')
plt.xlabel('Win Share per Season')
plt.ylabel('Rebounds per Season')
# Out:
# Text(0,0.5,'Rebounds per Season')

# %%
plt.style.use('fivethirtyeight')
plt.axes(xlim=(0,1), ylim=(0,1))

plt.scatter(cluster_results[cluster_results.Cluster == 2].WS, 
            cluster_results[cluster_results.Cluster == 2].TRB)
plt.title('Win Share vs DRB for Bigmen starter/6th man')
plt.xlabel('Win Share per Season')
plt.ylabel('Rebounds per Season')
# Out:
# Text(0,0.5,'Rebounds per Season')

# %%
plt.style.use('fivethirtyeight')
plt.axes(xlim=(0,1), ylim=(0,1))

plt.scatter(cluster_results[cluster_results.Cluster == 3].WS, 
            cluster_results[cluster_results.Cluster == 3].TRB)
plt.title('Win Share vs DRB for Scrubs/Injury shortened')
plt.xlabel('Win Share per Season')
plt.ylabel('Rebounds per Season')
# Out:
# Text(0,0.5,'Rebounds per Season')

# %%
plt.style.use('fivethirtyeight')
plt.axes(xlim=(0,1), ylim=(0,1))

plt.scatter(cluster_results[cluster_results.Cluster == 4].WS, 
            cluster_results[cluster_results.Cluster == 4].TRB)
plt.title('Win Share vs DRB for Nonbig starter/6th man')
plt.xlabel('Win Share per Season')
plt.ylabel('Rebounds per Season')
# Out:
# Text(0,0.5,'Rebounds per Season')

# %%
plt.style.use('fivethirtyeight')
plt.axes(xlim=(0,1), ylim=(0,1))

plt.scatter(cluster_results[cluster_results.Cluster == 5].WS, 
            cluster_results[cluster_results.Cluster == 5].TRB)
plt.title('Win Share vs DRB for Nonbig allstar+')
plt.xlabel('Win Share per Season')
plt.ylabel('Rebounds per Season')
# Out:
# Text(0,0.5,'Rebounds per Season')

# %%
ingram = pd.read_csv('data/BrandonIngram.csv')
trae = pd.read_csv('data/TraeYoung.csv')

# %%
ingram[value_cols]
# Out:
#     G    MP   PER  OWS  DWS   WS  BPM  VORP   FG   FGA    ...      FT  FTA  \
# 0  79  2279   8.5 -1.0  0.7 -0.3 -3.8  -1.1  3.5   8.7    ...     1.7  2.7
# 1  59  1975  13.8  1.0  1.8  2.8 -1.3   0.4  6.1  12.9    ...     3.3  4.8
#
#    ORB  DRB  TRB  AST  STL  BLK  Years_In_NBA        PR
# 0  0.8  3.2  4.0  2.1  0.6  0.5             1  -0.10808
# 1  1.0  4.4  5.3  3.9  0.8  0.7             2  16.60382
#
# [2 rows x 24 columns]

# %%
trae[value_cols]
# Out:
#     G  MP  PER  OWS   DWS    WS   BPM  VORP    FG    FGA  ...      FT   FTA  \
# 0  74  36   13  7.4 -5.18  2.22 -2.05     0  4.29  14.14  ...    4.43  5.71
#
#     ORB   DRB   TRB   AST   STL   BLK  Years_In_NBA     PR
# 0  0.71  1.43  2.14  5.71  1.29  0.14             0 -4.215
#
# [1 rows x 24 columns]

# %%
with_young_guys = pd.concat([
    ingram[value_cols],
    trae[value_cols],
    numerical_data],
    axis=0
)
with_young_guys.head()
# Out:
#       G    MP   PER  OWS   DWS    WS   BPM  VORP    FG    FGA    ...       FT  \
# 0    79  2279   8.5 -1.0  0.70 -0.30 -3.80  -1.1  3.50   8.70    ...     1.70
# 1    59  1975  13.8  1.0  1.80  2.80 -1.30   0.4  6.10  12.90    ...     3.30
# 0    74    36  13.0  7.4 -5.18  2.22 -2.05   0.0  4.29  14.14    ...     4.43
# 199  76  2426  16.6  2.3  2.30  4.50 -0.30   1.1  6.40  12.40    ...     4.00
# 204  80  1943  13.6  0.9  2.40  3.30  0.10   1.0  3.80   8.30    ...     0.90
#
#       FTA   ORB   DRB   TRB   AST   STL   BLK  Years_In_NBA        PR
# 0    2.70  0.80  3.20  4.00  2.10  0.60  0.50             1  -0.10808
# 1    4.80  1.00  4.40  5.30  3.90  0.80  0.70             2  16.60382
# 0    5.71  0.71  1.43  2.14  5.71  1.29  0.14             0  -4.21500
# 199  5.50  2.80  5.10  7.90  1.30  0.90  0.70             3  16.11847
# 204  1.30  1.20  3.80  5.00  2.10  0.70  1.10             3   6.76391
#
# [5 rows x 24 columns]

# %% [markdown]
# 1 and 2 are Ingram, 3 is Trae

# %%
rookie_data_normalized = MinMaxScaler().fit_transform(with_young_guys)
rookie_data_normalized = pd.DataFrame(
                    rookie_data_normalized,
                    columns=with_young_guys.columns) 
rookie_data_normalized.head()
# Out:
#          G       MP      PER      OWS      DWS       WS      BPM     VORP  \
# 0  0.92857  0.65395  0.45107  0.10227  0.41176  0.05936  0.74350  0.06897
# 1  0.69048  0.56671  0.47519  0.21591  0.48880  0.20091  0.76592  0.17241
# 2  0.86905  0.01033  0.47155  0.57955  0.00000  0.17443  0.75919  0.14483
# 3  0.89286  0.69613  0.48794  0.28977  0.52381  0.27854  0.77489  0.22069
# 4  0.94048  0.55753  0.47428  0.21023  0.53081  0.22374  0.77848  0.21379
#
#         FG      FGA   ...          FT      FTA      ORB      DRB      TRB  \
# 0  0.28689  0.31295   ...     0.18085  0.20611  0.11765  0.27826  0.24540
# 1  0.50000  0.46403   ...     0.35106  0.36641  0.14706  0.38261  0.32515
# 2  0.35164  0.50863   ...     0.47128  0.43588  0.10441  0.12435  0.13129
# 3  0.52459  0.44604   ...     0.42553  0.41985  0.41176  0.44348  0.48466
# 4  0.31148  0.29856   ...     0.09574  0.09924  0.17647  0.33043  0.30675
#
#        AST      STL      BLK  Years_In_NBA       PR
# 0  0.17949  0.20690  0.11111       0.04762  0.38111
# 1  0.33333  0.27586  0.15556       0.09524  0.52518
# 2  0.48803  0.44483  0.03111       0.00000  0.34570
# 3  0.11111  0.31034  0.15556       0.14286  0.52099
# 4  0.17949  0.24138  0.24444       0.14286  0.44035
#
# [5 rows x 24 columns]

# %%
ingram_normalized = rookie_data_normalized[rookie_data_normalized.index < 2]
ingram_normalized
# Out:
#          G       MP      PER      OWS      DWS       WS      BPM     VORP  \
# 0  0.92857  0.65395  0.45107  0.10227  0.41176  0.05936  0.74350  0.06897
# 1  0.69048  0.56671  0.47519  0.21591  0.48880  0.20091  0.76592  0.17241
#
#         FG      FGA   ...          FT      FTA      ORB      DRB      TRB  \
# 0  0.28689  0.31295   ...     0.18085  0.20611  0.11765  0.27826  0.24540
# 1  0.50000  0.46403   ...     0.35106  0.36641  0.14706  0.38261  0.32515
#
#        AST      STL      BLK  Years_In_NBA       PR
# 0  0.17949  0.20690  0.11111       0.04762  0.38111
# 1  0.33333  0.27586  0.15556       0.09524  0.52518
#
# [2 rows x 24 columns]

# %%
trae_normalized = rookie_data_normalized[rookie_data_normalized.index == 2]
trae_normalized
# Out:
#          G       MP      PER      OWS  DWS       WS      BPM     VORP  \
# 2  0.86905  0.01033  0.47155  0.57955  0.0  0.17443  0.75919  0.14483
#
#         FG      FGA   ...         FT      FTA      ORB      DRB      TRB  \
# 2  0.35164  0.50863   ...    0.47128  0.43588  0.10441  0.12435  0.13129
#
#        AST      STL      BLK  Years_In_NBA      PR
# 2  0.48803  0.44483  0.03111           0.0  0.3457
#
# [1 rows x 24 columns]

# %%
kmeans_cluster(rookie_data_normalized, 6).head()
# Out:
#          G       MP      PER      OWS      DWS       WS      BPM     VORP  \
# 0  0.92857  0.65395  0.45107  0.10227  0.41176  0.05936  0.74350  0.06897
# 1  0.69048  0.56671  0.47519  0.21591  0.48880  0.20091  0.76592  0.17241
# 2  0.86905  0.01033  0.47155  0.57955  0.00000  0.17443  0.75919  0.14483
# 3  0.89286  0.69613  0.48794  0.28977  0.52381  0.27854  0.77489  0.22069
# 4  0.94048  0.55753  0.47428  0.21023  0.53081  0.22374  0.77848  0.21379
#
#         FG      FGA   ...         FTA      ORB      DRB      TRB      AST  \
# 0  0.28689  0.31295   ...     0.20611  0.11765  0.27826  0.24540  0.17949
# 1  0.50000  0.46403   ...     0.36641  0.14706  0.38261  0.32515  0.33333
# 2  0.35164  0.50863   ...     0.43588  0.10441  0.12435  0.13129  0.48803
# 3  0.52459  0.44604   ...     0.41985  0.41176  0.44348  0.48466  0.11111
# 4  0.31148  0.29856   ...     0.09924  0.17647  0.33043  0.30675  0.17949
#
#        STL      BLK  Years_In_NBA       PR  Cluster
# 0  0.20690  0.11111       0.04762  0.38111        5
# 1  0.27586  0.15556       0.09524  0.52518        5
# 2  0.44483  0.03111       0.00000  0.34570        5
# 3  0.31034  0.15556       0.14286  0.52099        1
# 4  0.24138  0.24444       0.14286  0.44035        4
#
# [5 rows x 25 columns]
