# 16  84.2  1.3 %  85.3  0.1 %  75.0  0.5 %

# %%
pitch_velo = pitches[['Season','FBv','SLv','CBv','CHv']].sort_values(by=['Season'],ascending=False)
pitch_velo
# Out:
#     Season   FBv   SLv   CBv   CHv
# 16    2018  92.7  84.1  79.0  84.2
# 15    2017  92.8  84.4  78.6  84.2
# 14    2016  92.3  84.1  77.9  83.6
# 13    2015  92.1  84.0  77.9  83.5
# 12    2014  91.8  83.7  77.4  83.3
# 11    2013  91.7  83.3  77.3  82.9
# 10    2012  91.6  83.1  77.0  82.8
# 9     2011  91.5  83.4  76.7  82.5
# 8     2010  91.2  83.3  76.3  82.2
# 7     2009  91.2  83.0  76.4  82.2
# 6     2008  90.7  82.7  75.9  81.5
# 5     2007  90.3  82.4  75.1  81.1
# 4     2006  90.5  82.5  75.5  81.1
# 3     2005  90.1  82.5  75.4  80.8
# 2     2004  90.1  82.8  75.7  80.9
# 1     2003  89.4  81.7  75.1  79.6
# 0     2002  89.0  80.4  75.0  79.5

# %%
batting = pd.read_csv('data/by_year_bat_avg.csv')

# %%
batting.columns
# Out:
# Index(['Year', 'Tms', '#Bat', 'BatAge', 'R/G', 'G', 'PA', 'AB', 'R', 'H', '2B',
#        '3B', 'HR', 'RBI', 'SB', 'CS', 'BB', 'SO', 'BA', 'OBP', 'SLG', 'OPS',
#        'TB', 'GDP', 'HBP', 'SH', 'SF', 'IBB'],
#       dtype='object')

# %%
batting_clean = batting[['Year','R/G','HR','R','SO','BA']][batting.Year >= 2002]

# %%
batting_clean
# Out:
#     Year   R/G    HR     R    SO     BA
# 0   2018  4.39  1.15  4.39  8.51  0.246
# 1   2017  4.65  1.26  4.65  8.25  0.255
# 2   2016  4.48  1.16  4.48  8.03  0.255
# 3   2015  4.25  1.01  4.25  7.71  0.254
# 4   2014  4.07  0.86  4.07  7.70  0.251
# 5   2013  4.17  0.96  4.17  7.55  0.253
# 6   2012  4.32  1.02  4.32  7.50  0.255
# 7   2011  4.28  0.94  4.28  7.10  0.255
# 8   2010  4.38  0.95  4.38  7.06  0.257
# 9   2009  4.61  1.04  4.61  6.91  0.262
# 10  2008  4.65  1.00  4.65  6.77  0.264
# 11  2007  4.80  1.02  4.80  6.62  0.268
# 12  2006  4.86  1.11  4.86  6.52  0.269
# 13  2005  4.59  1.03  4.59  6.30  0.264
# 14  2004  4.81  1.12  4.81  6.55  0.266
# 15  2003  4.73  1.07  4.73  6.34  0.264
# 16  2002  4.62  1.04  4.62  6.47  0.261

# %%
batting_new_col = batting_clean.columns.values
batting_new_col[0] = 'Season'
batting_clean.columns = batting_new_col
batting_clean
# Out:
#     Season   R/G    HR     R    SO     BA
# 0     2018  4.39  1.15  4.39  8.51  0.246
# 1     2017  4.65  1.26  4.65  8.25  0.255
# 2     2016  4.48  1.16  4.48  8.03  0.255
# 3     2015  4.25  1.01  4.25  7.71  0.254
# 4     2014  4.07  0.86  4.07  7.70  0.251
# 5     2013  4.17  0.96  4.17  7.55  0.253
# 6     2012  4.32  1.02  4.32  7.50  0.255
# 7     2011  4.28  0.94  4.28  7.10  0.255
# 8     2010  4.38  0.95  4.38  7.06  0.257
# 9     2009  4.61  1.04  4.61  6.91  0.262
# 10    2008  4.65  1.00  4.65  6.77  0.264
# 11    2007  4.80  1.02  4.80  6.62  0.268
# 12    2006  4.86  1.11  4.86  6.52  0.269
# 13    2005  4.59  1.03  4.59  6.30  0.264
# 14    2004  4.81  1.12  4.81  6.55  0.266
# 15    2003  4.73  1.07  4.73  6.34  0.264
# 16    2002  4.62  1.04  4.62  6.47  0.261

# %%
merged = batting_clean.set_index('Season', drop=False).join(pitch_velo.set_index('Season'))
merged
# Out:
#         Season   R/G    HR     R    SO     BA   FBv   SLv   CBv   CHv
# Season
# 2018      2018  4.39  1.15  4.39  8.51  0.246  92.7  84.1  79.0  84.2
# 2017      2017  4.65  1.26  4.65  8.25  0.255  92.8  84.4  78.6  84.2
# 2016      2016  4.48  1.16  4.48  8.03  0.255  92.3  84.1  77.9  83.6
# 2015      2015  4.25  1.01  4.25  7.71  0.254  92.1  84.0  77.9  83.5
# 2014      2014  4.07  0.86  4.07  7.70  0.251  91.8  83.7  77.4  83.3
# 2013      2013  4.17  0.96  4.17  7.55  0.253  91.7  83.3  77.3  82.9
# 2012      2012  4.32  1.02  4.32  7.50  0.255  91.6  83.1  77.0  82.8
# 2011      2011  4.28  0.94  4.28  7.10  0.255  91.5  83.4  76.7  82.5
# 2010      2010  4.38  0.95  4.38  7.06  0.257  91.2  83.3  76.3  82.2
# 2009      2009  4.61  1.04  4.61  6.91  0.262  91.2  83.0  76.4  82.2
# 2008      2008  4.65  1.00  4.65  6.77  0.264  90.7  82.7  75.9  81.5
# 2007      2007  4.80  1.02  4.80  6.62  0.268  90.3  82.4  75.1  81.1
# 2006      2006  4.86  1.11  4.86  6.52  0.269  90.5  82.5  75.5  81.1
# 2005      2005  4.59  1.03  4.59  6.30  0.264  90.1  82.5  75.4  80.8
# 2004      2004  4.81  1.12  4.81  6.55  0.266  90.1  82.8  75.7  80.9
# 2003      2003  4.73  1.07  4.73  6.34  0.264  89.4  81.7  75.1  79.6
# 2002      2002  4.62  1.04  4.62  6.47  0.261  89.0  80.4  75.0  79.5

# %%
batted_ball = pd.read_csv('data/batted_ball.csv')

# %%
batted_ball_stripped = batted_ball[['Season','HR/FB','Soft%','Med%','Hard%']]

# %%
batted_ball_stripped.head()
# Out:
#    Season   HR/FB   Soft%    Med%   Hard%
# 0    2002  10.7 %  15.1 %  62.6 %  22.4 %
# 1    2003  11.2 %  15.9 %  60.5 %  23.6 %
# 2    2004  11.2 %  14.5 %  58.9 %  26.6 %
# 3    2005  10.6 %  15.8 %  56.4 %  27.8 %
# 4    2006  10.8 %  11.2 %  61.6 %  27.2 %

# %%
merged2 = merged.join(batted_ball_stripped.set_index('Season'))

# %%
merged2.head()
# Out:
#         Season   R/G    HR     R    SO     BA   FBv   SLv   CBv   CHv   HR/FB  \
# Season
# 2018      2018  4.39  1.15  4.39  8.51  0.246  92.7  84.1  79.0  84.2  12.6 %
# 2017      2017  4.65  1.26  4.65  8.25  0.255  92.8  84.4  78.6  84.2  13.7 %
# 2016      2016  4.48  1.16  4.48  8.03  0.255  92.3  84.1  77.9  83.6  12.8 %
# 2015      2015  4.25  1.01  4.25  7.71  0.254  92.1  84.0  77.9  83.5  11.4 %
# 2014      2014  4.07  0.86  4.07  7.70  0.251  91.8  83.7  77.4  83.3   9.5 %
#
#          Soft%    Med%   Hard%
# Season
# 2018    18.1 %  46.3 %  35.6 %
# 2017    18.9 %  49.3 %  31.8 %
# 2016    18.8 %  49.9 %  31.4 %
# 2015    18.6 %  52.5 %  28.8 %
# 2014    18.3 %  52.6 %  29.1 %

# %%
import numpy as np

# %%
soft = np.array(merged2['Soft%'])
med = np.array(merged2['Med%'])
hard = np.array(merged2['Hard%'])
hr_fb = np.array(merged2['HR/FB'])

# %%
soft[0][:-2]
# Out:
# '18.1'

# %%
def remove_percent(contact):
    no_perc = []
    for perc in contact:
        no_perc = np.append(no_perc, np.array(float(perc[:-2])))
    return no_perc

# %%
soft_clean = remove_percent(soft)
med_clean = remove_percent(med)
hard_clean = remove_percent(hard)
hr_fb_clean = remove_percent(hr_fb)

# %%
soft_clean
# Out:
# array([18.1, 18.9, 18.8, 18.6, 18.3, 16.5, 15.7, 24.3, 18.1, 15.7, 16.9,
#        18.2, 11.2, 15.8, 14.5, 15.9, 15.1])

# %%
soft_df = pd.DataFrame(soft_clean)
med_df = pd.DataFrame(med_clean)
hard_df = pd.DataFrame(hard_clean)
hr_fb_df = pd.DataFrame(hr_fb_clean)

# %%
merged2['Soft%'] = soft_df[0].values
merged2['Med%'] = med_df[0].values
merged2['Hard%'] = hard_df[0].values
merged2['HR/FB'] = hr_fb_df[0].values

# %%
merged2.head()
# Out:
#         Season   R/G    HR     R    SO     BA   FBv   SLv   CBv   CHv  HR/FB  \
# Season
# 2018      2018  4.39  1.15  4.39  8.51  0.246  92.7  84.1  79.0  84.2   12.6
# 2017      2017  4.65  1.26  4.65  8.25  0.255  92.8  84.4  78.6  84.2   13.7
# 2016      2016  4.48  1.16  4.48  8.03  0.255  92.3  84.1  77.9  83.6   12.8
# 2015      2015  4.25  1.01  4.25  7.71  0.254  92.1  84.0  77.9  83.5   11.4
# 2014      2014  4.07  0.86  4.07  7.70  0.251  91.8  83.7  77.4  83.3    9.5
#
#         Soft%  Med%  Hard%
# Season
# 2018     18.1  46.3   35.6
# 2017     18.9  49.3   31.8
# 2016     18.8  49.9   31.4
# 2015     18.6  52.5   28.8
# 2014     18.3  52.6   29.1

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
plt.rcParams["figure.figsize"] = (6, 6)

# %%
merged2.plot.scatter(x='FBv',y='SO');
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
merged2.plot.scatter(x='FBv',y='Hard%');
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
plt.plot(merged2.Season, merged2.FBv, color='g')
plt.plot(merged2.Season, merged2.SLv, color='red')
plt.plot(merged2.Season, merged2.CBv, color='blue')
plt.plot(merged2.Season, merged2.CHv, color='orange')
plt.xlabel('Season')
plt.ylabel('Velocity')
plt.title('Avg Pitch Velocity by Season')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">
