# %% [markdown]
# # SVD Exercises
#
# Congrats, you just got hired as the lead data scientist for Minipreço! Your boss has some data of invoices for purchases and she thinks that a recommender system would lead to higher sales. Using the `retail.csv` and the **SVD** from class lets make this happen!
#
# *Hint: The SVD notebook from class will help a lot!*

# %% [markdown]
# ### Load in the data

# %%
import pandas as pd
import numpy as np

# %%
retail = pd.read_csv('data/retail.csv')
retail.head()
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    573744     21314       SMALL GLASS HEART TRINKET POT         8
# 1    573744     21704             BAG 250g SWIRLY MARBLES        12
# 2    573744     21791  VINTAGE HEADS AND TAILS CARD GAME         12
# 3    573744     21892  TRADITIONAL WOODEN CATCH CUP GAME         12
# 4    573744     21915              RED  HARMONICA IN BOX         12
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2011-11-01 08:16:00       2.10     17733.0  United Kingdom
# 1  2011-11-01 08:16:00       0.85     17733.0  United Kingdom
# 2  2011-11-01 08:16:00       1.25     17733.0  United Kingdom
# 3  2011-11-01 08:16:00       1.25     17733.0  United Kingdom
# 4  2011-11-01 08:16:00       1.25     17733.0  United Kingdom

# %% [markdown]
# sum quantities of separate purchases

# %%
pivot = pd.pivot_table(retail, values='Quantity', index=['CustomerID','StockCode','Description'], aggfunc=np.sum).reset_index()

# %%
pivot.head()
# Out:
#    CustomerID StockCode                          Description  Quantity
# 0     12349.0     20685                DOORMAT RED RETROSPOT         6
# 1     12349.0     20914  SET/5 RED RETROSPOT LID GLASS BOWLS         6
# 2     12349.0     21086          SET/6 RED SPOTTY PAPER CUPS        12
# 3     12349.0     21136         PAINTED METAL PEARS ASSORTED        16
# 4     12349.0     21231       SWEETHEART CERAMIC TRINKET BOX        36

# %% [markdown]
# ### Create sparse CustomerID and Quantity matrix

# %%
retail_mtx_df = pivot.pivot_table(values='Quantity', index='CustomerID',
                                     columns='StockCode')
stockCode_index = retail_mtx_df.columns

# %%
retail_mtx_df.shape
# Out:
# (1711, 2704)

# %%
retail_mtx_df.head()
# Out:
# StockCode   10080  10120  10124A  10124G  10125  10135  11001  15030  15034  \
# CustomerID
# 12349.0       NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN    NaN
# 12352.0       NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN    NaN
# 12356.0       NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN    NaN
# 12357.0       NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN    NaN
# 12362.0       NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN    NaN
#
# StockCode   15036  ...   90214M  90214N  90214S  BANK CHARGES  C2  CRUK   D  \
# CustomerID         ...
# 12349.0       NaN  ...      NaN     NaN     NaN           NaN NaN   NaN NaN
# 12352.0       NaN  ...      NaN     NaN     NaN           NaN NaN   NaN NaN
# 12356.0       NaN  ...      NaN     NaN     NaN           NaN NaN   NaN NaN
# 12357.0       NaN  ...      NaN     NaN     NaN           NaN NaN   NaN NaN
# 12362.0       NaN  ...      NaN     NaN     NaN           NaN NaN   NaN NaN
#
# StockCode   DOT   M  POST
# CustomerID
# 12349.0     NaN NaN   1.0
# 12352.0     NaN NaN   2.0
# 12356.0     NaN NaN   NaN
# 12357.0     NaN NaN   NaN
# 12362.0     NaN NaN   4.0
#
# [5 rows x 2704 columns]

# %%
from scipy.sparse import coo_matrix
retail_mtx = retail_mtx_df.fillna(0).as_matrix().copy()

retail_sparse_mtx = coo_matrix(retail_mtx)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
retail_sparse_mtx
# Out:
# <1711x2704 sparse matrix of type '<class 'numpy.float64'>'
# 	with 55529 stored elements in COOrdinate format>

# %% [markdown]
# ### Take the SVD of the matrix
# *Make degree 10*

# %%
from scipy.sparse.linalg import svds

# %%
U,s, V = svds(retail_mtx,  k=10)

# %%
U.shape, s.shape, V.shape
# Out:
# ((1711, 10), (10,), (10, 2704))

# %%
s_diag_matrix = np.zeros((s.shape[0], s.shape[0]))

for i in range(s.shape[0]):
    s_diag_matrix[i,i] = s[i]

# %% [markdown]
# ### Multiply the decompostion back to get approx matrix

# %%
retail_svd = U @ s_diag_matrix @ V

# %%
retail_svd.shape
# Out:
# (1711, 2704)

# %%
retail_svd
# Out:
# array([[ 5.36494264e-04,  1.29129903e-03,  2.01672568e-05, ...,
#          5.93395296e-04, -1.53222680e-02,  5.37717788e-02],
#        [ 4.88798183e-05,  1.22248826e-04,  1.72817625e-06, ...,
#          5.32174054e-05,  1.43823670e-03,  4.46494237e-03],
#        [ 6.73044271e-06,  2.06596698e-05,  1.97987422e-07, ...,
#          7.68056356e-06, -5.90230711e-05,  1.90200304e-04],
#        ...,
#        [-1.94857279e-19, -4.95629750e-19, -7.05704244e-21, ...,
#         -2.57072143e-19, -6.34674231e-15, -1.33642146e-17],
#        [-6.49664659e-08, -1.88452450e-07, -1.44252403e-09, ...,
#         -7.13121817e-08,  7.01330694e-07, -1.32385267e-07],
#        [ 1.52340092e-03,  4.37867466e-03,  4.31003493e-05, ...,
#          1.75878305e-03,  3.43253295e-01,  5.01966611e-02]])

# %% [markdown]
# ### Create recommendation function
#
# Using the approx matrix from above we can give recommendations. You got this!

# %%
customer_id_dict = dict(zip(pivot.CustomerID.unique(), range(len(pivot.CustomerID.unique()))))

# %%
customer_id = 12541.0

customer_matrix_position = customer_id_dict[customer_id]

# %%
customer_matrix_position
# Out:
# 63

# %%
pivot[pivot.CustomerID==customer_id].head()
# Out:
#    CustomerID StockCode                          Description  Quantity
# 0     12349.0     20685                DOORMAT RED RETROSPOT         6
# 1     12349.0     20914  SET/5 RED RETROSPOT LID GLASS BOWLS         6
# 2     12349.0     21086          SET/6 RED SPOTTY PAPER CUPS        12
# 3     12349.0     21136         PAINTED METAL PEARS ASSORTED        16
# 4     12349.0     21231       SWEETHEART CERAMIC TRINKET BOX        36

# %%
stock_codes = pivot.StockCode

# %%
customer_bought_items = pivot[pivot.CustomerID==customer_id].StockCode.tolist()
customer_recommendations = list(zip(stock_codes, np.argsort(retail_svd[customer_matrix_position])))

# %%
customer_recommendations[:10]
# Out:
# [('21314', 644),
#  ('21704', 2702),
#  ('21791', 228),
#  ('21892', 908),
#  ('21915', 904),
#  ('22065', 905),
#  ('22340', 612),
#  ('22577', 906),
#  ('22578', 907),
#  ('22579', 229)]

# %%
customer_recommendations = list(
                    map(
                     lambda x: x[0],
                     sorted(customer_recommendations, key=lambda x: x[1])
                    )
)
customer_recommendations = [StockCode for StockCode in customer_recommendations if StockCode not in customer_bought_items]

# %%
customer_recommendations[:10]
# Out:
# ['22382',
#  '21108',
#  '47566',
#  '23352',
#  '23284',
#  '23298',
#  '22863',
#  '23284',
#  '23491',
#  '23145']

# %%
pivot[pivot.StockCode.isin(customer_recommendations[:5])]
# Out:
#        CustomerID StockCode                         Description  Quantity
# 241       12374.0     21108  FAIRY CAKE FLANNEL ASSORTED COLOUR        18
# 287       12380.0     22382          LUNCH BAG SPACEBOY DESIGN         10
# 417       12391.0     47566                       PARTY BUNTING         1
# 605       12415.0     22382          LUNCH BAG SPACEBOY DESIGN        100
# 629       12421.0     21108  FAIRY CAKE FLANNEL ASSORTED COLOUR        18
# 986       12451.0     22382          LUNCH BAG SPACEBOY DESIGN         10
# 1274      12476.0     23284       DOORMAT KEEP CALM AND COME IN        16
# 1746      12517.0     23284       DOORMAT KEEP CALM AND COME IN         2
# 1962      12540.0     47566                       PARTY BUNTING         8
# 1985      12541.0     23284       DOORMAT KEEP CALM AND COME IN         2
# 2237      12577.0     23284       DOORMAT KEEP CALM AND COME IN         1
# 2673      12626.0     22382          LUNCH BAG SPACEBOY DESIGN         10
# 2752      12638.0     21108  FAIRY CAKE FLANNEL ASSORTED COLOUR        18
# 3031      12670.0     23352       ROLL WRAP 50'S RED CHRISTMAS         12
# 3103      12681.0     22382          LUNCH BAG SPACEBOY DESIGN         10
# 3211      12682.0     47566                       PARTY BUNTING         4
# 3234      12684.0     22382          LUNCH BAG SPACEBOY DESIGN         10
# 3289      12689.0     22382          LUNCH BAG SPACEBOY DESIGN         10
# 3384      12705.0     23284       DOORMAT KEEP CALM AND COME IN         4
# 3685      12731.0     22382          LUNCH BAG SPACEBOY DESIGN         30
# 3806      12748.0     21108  FAIRY CAKE FLANNEL ASSORTED COLOUR        28
# 4051      12748.0     22382          LUNCH BAG SPACEBOY DESIGN         13
# 4354      12748.0     23284       DOORMAT KEEP CALM AND COME IN         1
# 4395      12748.0     23352       ROLL WRAP 50'S RED CHRISTMAS          8
# 4719      12778.0     21108  FAIRY CAKE FLANNEL ASSORTED COLOUR        36
# 4940      12838.0     23352       ROLL WRAP 50'S RED CHRISTMAS          3
# 5033      12841.0     47566                       PARTY BUNTING         2
# 5275      12867.0     22382          LUNCH BAG SPACEBOY DESIGN          3
# 5330      12867.0     47566                       PARTY BUNTING         3
# 5413      12882.0     23284       DOORMAT KEEP CALM AND COME IN        60
# ...           ...       ...                                 ...       ...
# 50811     17758.0     23284       DOORMAT KEEP CALM AND COME IN         2
# 50999     17768.0     23284       DOORMAT KEEP CALM AND COME IN         3
# 51071     17769.0     47566                       PARTY BUNTING         2
# 51203     17779.0     23284       DOORMAT KEEP CALM AND COME IN         6
# 51241     17791.0     22382          LUNCH BAG SPACEBOY DESIGN          5
# 51377     17799.0     22382          LUNCH BAG SPACEBOY DESIGN          4
# 51591     17811.0     23284       DOORMAT KEEP CALM AND COME IN         2
# 51700     17812.0     23284       DOORMAT KEEP CALM AND COME IN         1
# 51707     17812.0     23352       ROLL WRAP 50'S RED CHRISTMAS          1
# 52052     17841.0     22382          LUNCH BAG SPACEBOY DESIGN          6
# 52358     17841.0     47566                       PARTY BUNTING         6
# 52711     17883.0     23352       ROLL WRAP 50'S RED CHRISTMAS          2
# 53155     17964.0     23352       ROLL WRAP 50'S RED CHRISTMAS          3
# 53280     17974.0     23284       DOORMAT KEEP CALM AND COME IN         1
# 53546     18016.0     23284       DOORMAT KEEP CALM AND COME IN         2
# 53832     18036.0     22382          LUNCH BAG SPACEBOY DESIGN          2
# 53965     18044.0     23284       DOORMAT KEEP CALM AND COME IN         2
# 54054     18069.0     47566                       PARTY BUNTING         1
# 54152     18082.0     23284       DOORMAT KEEP CALM AND COME IN         2
# 54324     18104.0     23284       DOORMAT KEEP CALM AND COME IN         4
# 54847     18130.0     21108  FAIRY CAKE FLANNEL ASSORTED COLOUR        18
# 54857     18130.0     22382          LUNCH BAG SPACEBOY DESIGN         10
# 54879     18130.0     23352       ROLL WRAP 50'S RED CHRISTMAS         12
# 54929     18139.0     47566                       PARTY BUNTING       300
# 55147     18164.0     23284       DOORMAT KEEP CALM AND COME IN         2
# 55307     18205.0     23284       DOORMAT KEEP CALM AND COME IN         2
# 55392     18217.0     21108  FAIRY CAKE FLANNEL ASSORTED COLOUR        18
# 55521     18249.0     21108  FAIRY CAKE FLANNEL ASSORTED COLOUR        18
# 55565     18274.0     21108  FAIRY CAKE FLANNEL ASSORTED COLOUR         0
# 55611     18283.0     22382          LUNCH BAG SPACEBOY DESIGN          5
#
# [425 rows x 4 columns]

# %%
def recommend(customer_id, num_results=5):
    """ Reccomends items to users
    Args:
      customer_id : the customer id
      num_results: the number of recs to give
    Returns:
      rec_ids: list of recommended item ids
      rec_names: list of recommended item description/names
    """
    customer_matrix_position = customer_id_dict[customer_id]
    customer_bought_items = retail[retail.CustomerID==customer_id].StockCode.tolist()
    customer_recommendations = list(zip(stock_codes, np.argsort(retail_svd[customer_matrix_position])))
    customer_recommendations = list(
                        map(
                         lambda x: x[0],
                         sorted(customer_recommendations, key=lambda x: x[1])
                        )
    )
    customer_recommendations = [StockCode for StockCode in customer_recommendations if StockCode not in customer_bought_items]
    return(retail[retail.StockCode.isin(customer_recommendations[:5])][['StockCode','Description']])
    
    raise NotImplementedError("Finish the function...")

# %%
recommend(12349.0, 5)
# Out:
#       StockCode                         Description
# 48       85099B             JUMBO BAG RED RETROSPOT
# 78        23012     GLASS APOTHECARY BOTTLE PERFUME
# 161      85099B             JUMBO BAG RED RETROSPOT
# 172       23343        JUMBO BAG VINTAGE CHRISTMAS
# 253       23343        JUMBO BAG VINTAGE CHRISTMAS
# 254      85099B             JUMBO BAG RED RETROSPOT
# 318       22113         GREY HEART HOT WATER BOTTLE
# 401      84596B  SMALL DOLLY MIX DESIGN ORANGE BOWL
# 458       22113         GREY HEART HOT WATER BOTTLE
# 790      85099B             JUMBO BAG RED RETROSPOT
# 954       22113         GREY HEART HOT WATER BOTTLE
# 980       23343        JUMBO BAG VINTAGE CHRISTMAS
# 1060      23343        JUMBO BAG VINTAGE CHRISTMAS
# 1061     85099B             JUMBO BAG RED RETROSPOT
# 1231     84596B  SMALL DOLLY MIX DESIGN ORANGE BOWL
# 1339      22113         GREY HEART HOT WATER BOTTLE
# 1371      23012     GLASS APOTHECARY BOTTLE PERFUME
# 1410      22113         GREY HEART HOT WATER BOTTLE
# 1411      22113         GREY HEART HOT WATER BOTTLE
# 1558     84596B  SMALL DOLLY MIX DESIGN ORANGE BOWL
# 1563     85099B             JUMBO BAG RED RETROSPOT
# 1974      23343        JUMBO BAG VINTAGE CHRISTMAS
# 1983      23012     GLASS APOTHECARY BOTTLE PERFUME
# 1991      23012     GLASS APOTHECARY BOTTLE PERFUME
# 2234      22113         GREY HEART HOT WATER BOTTLE
# 2665     85099B             JUMBO BAG RED RETROSPOT
# 2724     85099B             JUMBO BAG RED RETROSPOT
# 2735      22113         GREY HEART HOT WATER BOTTLE
# 2829      22113         GREY HEART HOT WATER BOTTLE
# 2841      23012     GLASS APOTHECARY BOTTLE PERFUME
# ...         ...                                 ...
# 81887     22113         GREY HEART HOT WATER BOTTLE
# 81896    85099B             JUMBO BAG RED RETROSPOT
# 82000     22113         GREY HEART HOT WATER BOTTLE
# 82055     23343        JUMBO BAG VINTAGE CHRISTMAS
# 82161    85099B             JUMBO BAG RED RETROSPOT
# 82290    85099B             JUMBO BAG RED RETROSPOT
# 82320     23343        JUMBO BAG VINTAGE CHRISTMAS
# 82360     22113         GREY HEART HOT WATER BOTTLE
# 82443    85099B             JUMBO BAG RED RETROSPOT
# 82500     22113         GREY HEART HOT WATER BOTTLE
# 82527    84596B  SMALL DOLLY MIX DESIGN ORANGE BOWL
# 82621    84596B  SMALL DOLLY MIX DESIGN ORANGE BOWL
# 82832     23343        JUMBO BAG VINTAGE CHRISTMAS
# 82866    85099B             JUMBO BAG RED RETROSPOT
# 82874     23343        JUMBO BAG VINTAGE CHRISTMAS
# 83022    84596B  SMALL DOLLY MIX DESIGN ORANGE BOWL
# 83114     23343        JUMBO BAG VINTAGE CHRISTMAS
# 83220    85099B             JUMBO BAG RED RETROSPOT
# 83284    85099B             JUMBO BAG RED RETROSPOT
# 83407     23343        JUMBO BAG VINTAGE CHRISTMAS
# 83548    84596B  SMALL DOLLY MIX DESIGN ORANGE BOWL
# 83572    85099B             JUMBO BAG RED RETROSPOT
# 84034    85099B             JUMBO BAG RED RETROSPOT
# 84160    85099B             JUMBO BAG RED RETROSPOT
# 84246     22113         GREY HEART HOT WATER BOTTLE
# 84335    85099B             JUMBO BAG RED RETROSPOT
# 84374     23343        JUMBO BAG VINTAGE CHRISTMAS
# 84392     22113         GREY HEART HOT WATER BOTTLE
# 84406     23012     GLASS APOTHECARY BOTTLE PERFUME
# 84441     23343        JUMBO BAG VINTAGE CHRISTMAS
#
# [702 rows x 2 columns]

# %% [markdown]
# ### BONUS!
# This only works for customers already in the data. How would you change this to make it recommend for a new customer that has purchased a list of items?
